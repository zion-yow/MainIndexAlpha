# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat as loadmat
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.unicode_minus'] = False

# Suppress warnings`
warnings.filterwarnings("ignore")

# %%
import imp

# %%
imp.reload(xy)
# Out:
# <module 'xy' from 'E:\\PyProject\\factors\\DROP\\xy.py'>

# %%
import xy

# %% [markdown]
# # $因子描述：DROP$

# %% [markdown]
# ***下行标准差***

# %% [markdown]
# ## 计算

# %%
def find_drop_most(_arr):
    aa = np.argsort(_arr)<=30
    ss = np.nanstd(xy.rolling_window(_arr,20),axis=1)
    # bb = np.argsort(_arr)>=200
    
    return xy.rolling_window(_arr,20)[np.argsort(ss)>=200].reshape(-1).mean()

# %%
def cal_DROP(arr):
    _Drop = np.apply_along_axis(find_drop_most,1,xy.rolling_window(arr,240)[::240])
    Drop = pd.Series(_Drop,index = arr.index[::240])
    
    Drop.index = Drop.index.map(lambda x: x[:10])
    return Drop

# %%
iDrop50 = cal_DROP(xy.IndexMin50jq.volume.dropna())
iDrop300 = cal_DROP(xy.IndexMin300jq.volume.dropna())
iDrop500 = cal_DROP(xy.IndexMin500jq.volume.dropna())
iDrop1000 = cal_DROP(xy.IndexMin1000jq.volume.dropna())
# 参数平滑
iDrop1 = pd.concat([
    iDrop50.rename('50'),
    iDrop300.rename('300'),
    iDrop500.rename('500'),
    iDrop1000.rename('1000'),
],axis=1).rolling(1).mean().shift(1)

iDrop3 = pd.concat([
    iDrop50.rename('50'),
    iDrop300.rename('300'),
    iDrop500.rename('500'),
    iDrop1000.rename('1000'),
],axis=1).rolling(3).mean().shift(1)

iDrop4 = pd.concat([
    iDrop50.rename('50'),
    iDrop300.rename('300'),
    iDrop500.rename('500'),
    iDrop1000.rename('1000'),
],axis=1).rolling(4).mean().shift(1)

iDrop5 = pd.concat([
    iDrop50.rename('50'),
    iDrop300.rename('300'),
    iDrop500.rename('500'),
    iDrop1000.rename('1000'),
],axis=1).rolling(5).mean().shift(1)


iDrop = (iDrop3 + iDrop4 + iDrop5) / xy.index_volume.T.loc['2016-01-07':,['50','300','500','1000']].shift(1)/6

# %%
# 分组收益率
xy.cal_rate_group(
    (iDrop).T,
    xy.Index_rets,
    group_num=4,
    masks=1
).cumsum().plot()
# Out:
# -0.0034813693095103585
# 1 0.5025380710659898
# 2 0.5025380710659898
# 3 0.5025380710659898
# 4 0.5025380710659898
# <Axes: >

# %%
# 单因子强弱
DNM_select, DNM_rets = xy.single_Factor_backtest(
    iDrop.T.loc[['50','1000'],'2016-01-28':],# ['50','1000']
    xy.Index_rets.loc[['50','1000'],'2016-01-28':],
    _side=-1,
    fee=0.00,
    name='DNM'
)
# Out:
# 248.0
# yoy: -0.008966333441125572
#  mdd: -0.5750724085532996
#  sharpe: -0.045848582193972184
#  rankIC: 0.03163841807909603
#  rankIR: 0.03164532169298503
#  win%: 0.4688183807439825
#  gain_loss%: -1.05699867036423

# %%
# 单因子强弱
DNM_select, DNM_rets = xy.single_Factor_backtest(
    org_New_TSR1_idx.loc[['50','1000'],:],# ['50','1000']
    xy.Index_rets.loc[['50','1000'],'2016-01-28':],
    _side=1,
    fee=0.00,
    name='DNM'
)
# Out:
# 746.0
# yoy: 0.16428149086737895
#  mdd: -0.40562485469703125
#  sharpe: 0.8412738067606186
#  rankIC: 0.0032608695652173877
#  rankIR: 0.0032600006712100596
#  win%: 0.4965034965034965
#  gain_loss%: -1.1458073751172746

# %%
# 单因子强弱
DNM_select, DNM_rets = xy.single_Factor_backtest(
    New_TSR1_idx.loc[['50','1000'],:],# ['50','1000']
    xy.Index_rets.loc[['50','1000'],'2016-01-28':],
    _side=1,
    fee=0.00,
    name='DNM'
)
# Out:
# 838.0
# yoy: 0.2552198437393319
#  mdd: -0.3682993551340993
#  sharpe: 1.2943384946184429
#  rankIC: 0.039049235993208815
#  rankIR: 0.03906798247372473
#  win%: 0.5142857142857142
#  gain_loss%: -1.1520449517099678

# %%
New_TSR1_idx
# Out:
#       2016-01-04  2016-01-05  2016-01-06  2016-01-07  2016-01-08  2016-01-11  \
# 50      0.962962    0.905180    1.155897    0.606296    0.764528    1.313461
# 300     0.302050    0.373900    0.337662    0.595247    0.281042    0.131593
# 500     0.136045    0.142389   -0.280665    0.281338    0.423233   -0.395867
# 1000   -1.401057   -1.421469   -1.212894   -1.482881   -1.468804   -1.049187
#
#       2016-01-12  2016-01-13  2016-01-14  2016-01-15  ...  2023-05-24  \
# 50      1.311309    1.361990    1.242439    1.209194  ...    1.061463
# 300     0.086411    0.031007    0.295041    0.243965  ...   -1.350465
# 500    -0.314030   -0.401708   -0.462659   -0.266963  ...    0.082132
# 1000   -1.083691   -0.991289   -1.074822   -1.186196  ...    0.206869
#
#       2023-05-25  2023-05-26  2023-05-29  2023-05-30  2023-05-31  2023-06-01  \
# 50      1.293808    1.241196    1.215117    0.924308   -0.027575   -0.338067
# 300    -1.133674   -1.149904   -1.048389   -1.338408   -0.873608   -0.903887
# 500     0.038302   -0.303509   -0.536393   -0.159406   -0.505961   -0.184464
# 1000   -0.198436    0.212217    0.369666    0.573506    1.407143    1.426419
#
#       2023-06-02  2023-06-05  2023-06-06
# 50     -0.766041   -0.967313   -0.910719
# 300    -0.892070   -0.610647   -0.645957
# 500     0.480685    0.316520    0.257900
# 1000    1.177426    1.261440    1.298776
#
# [4 rows x 1805 columns]

# %%
# 单因子强弱
DNM_select, DNM_rets = xy.single_Factor_backtest(
    New_TSR1_idx.loc[['50','1000'],:],# ['50','1000']
    xy.Index_rets.loc[['50','1000'],'2016-01-28':],
    _side=1,
    fee=0.00,
    name='DNM'
)
# Out:
# 806.0
# yoy: 0.2476559274633037
#  mdd: -0.3904276092963336
#  sharpe: 1.2586119516269596
#  rankIC: 0.02518186905428091
#  rankIR: 0.025182808027500548
#  win%: 0.5074792243767313
#  gain_loss%: -1.1770526951239695

# %%
New_TSR1_idx
# Out:
#       2016-01-04  2016-01-05  2016-01-06  2016-01-07  2016-01-08  2016-01-11  \
# 50      1.162610    1.178631    1.071053    1.074626    1.172423    1.285050
# 300     0.279121    0.345265    0.455569    0.425751    0.317748    0.176470
# 500    -0.205534   -0.355443   -0.273406   -0.231368   -0.290028   -0.377569
# 1000   -1.236198   -1.168453   -1.253216   -1.269009   -1.200143   -1.083950
#
#       2016-01-12  2016-01-13  2016-01-14  2016-01-15  ...  2023-04-21  \
# 50      1.310740    1.336981    1.133745    1.127067  ...   -1.403125
# 300     0.047593    0.070889    0.265621    0.245809  ...    0.334108
# 500    -0.256579   -0.374990   -0.123074   -0.083570  ...    0.117248
# 1000   -1.101754   -1.032880   -1.276292   -1.289307  ...    0.951769
#
#       2023-04-24  2023-04-25  2023-04-26  2023-04-27  2023-04-28  2023-05-04  \
# 50     -1.293744   -1.175258   -1.489783   -1.418608   -1.378618   -1.321552
# 300     0.242778    0.428628    0.405793    0.106269   -0.044465   -0.009263
# 500    -0.072439   -0.387053    0.422912    0.416233    0.505567    0.236524
# 1000    1.123405    1.133683    0.661078    0.896107    0.917517    1.094291
#
#       2023-05-05  2023-05-08  2023-05-09
# 50     -0.932959    0.169829   -0.659408
# 300    -0.164370    1.346187   -0.764973
# 500     1.414836   -0.827962    1.407017
# 1000   -0.317506   -0.688054    0.017364
#
# [4 rows x 1785 columns]

# %%
import jqdatasdk
jqdatasdk.auth(username='13602599243',password='JoinQuant897617209')
# Out:
# auth success

# %%
new_idx = []
for i in xy.weights1000.index:
    if i[-2:] == 'SZ':
        new_idx.append(i[:-3]+'.XSHE')
    else:
        new_idx.append(i[:-3]+'.XSHG')

# %%
# Out:
# ['000005.XSHE',
#  '000006.XSHE',
#  '000008.XSHE',
#  '000010.XSHE',
#  '000011.XSHE',
#  '000014.XSHE',
#  '000016.XSHE',
#  '000018.XSHE',
#  '000019.XSHE',
#  '000025.XSHE',
#  '000028.XSHE',
#  '000029.XSHE',
#  '000030.XSHE',
#  '000032.XSHE',
#  '000034.XSHE',
#  '000035.XSHE',
#  '000036.XSHE',
#  '000038.XSHE',
#  '000040.XSHE',
#  '000042.XSHE',
#  '000048.XSHE',
#  '000049.XSHE',
#  '000055.XSHE',
#  '000056.XSHE',
#  '000058.XSHE',
#  '000059.XSHE',
#  '000061.XSHE',
#  '000065.XSHE',
#  '000070.XSHE',
#  '000088.XSHE',
#  '000089.XSHE',
#  '000090.XSHE',
#  '000096.XSHE',
#  '000150.XSHE',
#  '000151.XSHE',
#  '000153.XSHE',
#  '000155.XSHE',
#  '000158.XSHE',
#  '000159.XSHE',
#  '000301.XSHE',
#  '000403.XSHE',
#  '000404.XSHE',
#  '000407.XSHE',
#  '000409.XSHE',
#  '000410.XSHE',
#  '000416.XSHE',
#  '000419.XSHE',
#  '000422.XSHE',
#  '000423.XSHE',
#  '000426.XSHE',
#  '000428.XSHE',
#  '000429.XSHE',
#  '000488.XSHE',
#  '000498.XSHE',
#  '000503.XSHE',
#  '000506.XSHE',
#  '000507.XSHE',
#  '000514.XSHE',
#  '000516.XSHE',
#  '000517.XSHE',
#  '000518.XSHE',
#  '000520.XSHE',
#  '000521.XSHE',
#  '000523.XSHE',
#  '000525.XSHE',
#  '000528.XSHE',
#  '000529.XSHE',
#  '000530.XSHE',
#  '000531.XSHE',
#  '000532.XSHE',
#  '000533.XSHE',
#  '000536.XSHE',
#  '000537.XSHE',
#  '000539.XSHE',
#  '000540.XSHE',
#  '000543.XSHE',
#  '000544.XSHE',
#  '000545.XSHE',
#  '000546.XSHE',
#  '000548.XSHE',
#  '000550.XSHE',
#  '000551.XSHE',
#  '000552.XSHE',
#  '000553.XSHE',
#  '000554.XSHE',
#  '000555.XSHE',
#  '000557.XSHE',
#  '000558.XSHE',
#  '000560.XSHE',
#  '000561.XSHE',
#  '000564.XSHE',
#  '000566.XSHE',
#  '000567.XSHE',
#  '000570.XSHE',
#  '000571.XSHE',
#  '000573.XSHE',
#  '000576.XSHE',
#  '000582.XSHE',
#  '000584.XSHE',
#  '000589.XSHE',
#  '000591.XSHE',
#  '000592.XSHE',
#  '000597.XSHE',
#  '000600.XSHE',
#  '000601.XSHE',
#  '000603.XSHE',
#  '000606.XSHE',
#  '000607.XSHE',
#  '000612.XSHE',
#  '000615.XSHE',
#  '000620.XSHE',
#  '000626.XSHE',
#  '000627.XSHE',
#  '000631.XSHE',
#  '000637.XSHE',
#  '000639.XSHE',
#  '000650.XSHE',
#  '000652.XSHE',
#  '000657.XSHE',
#  '000662.XSHE',
#  '000663.XSHE',
#  '000665.XSHE',
#  '000666.XSHE',
#  '000667.XSHE',
#  '000670.XSHE',
#  '000672.XSHE',
#  '000673.XSHE',
#  '000676.XSHE',
#  '000681.XSHE',
#  '000682.XSHE',
#  '000683.XSHE',
#  '000685.XSHE',
#  '000687.XSHE',
#  '000688.XSHE',
#  '000690.XSHE',
#  '000697.XSHE',
#  '000700.XSHE',
#  '000701.XSHE',
#  '000705.XSHE',
#  '000708.XSHE',
#  '000710.XSHE',
#  '000711.XSHE',
#  '000712.XSHE',
#  '000713.XSHE',
#  '000717.XSHE',
#  '000718.XSHE',
#  '000719.XSHE',
#  '000720.XSHE',
#  '000722.XSHE',
#  '000726.XSHE',
#  '000727.XSHE',
#  '000731.XSHE',
#  '000733.XSHE',
#  '000735.XSHE',
#  '000737.XSHE',
#  '000739.XSHE',
#  '000751.XSHE',
#  '000752.XSHE',
#  '000757.XSHE',
#  '000758.XSHE',
#  '000760.XSHE',
#  '000761.XSHE',
#  '000762.XSHE',
#  '000766.XSHE',
#  '000767.XSHE',
#  '000782.XSHE',
#  '000788.XSHE',
#  '000789.XSHE',
#  '000790.XSHE',
#  '000791.XSHE',
#  '000793.XSHE',
#  '000795.XSHE',
#  '000796.XSHE',
#  '000797.XSHE',
#  '000799.XSHE',
#  '000800.XSHE',
#  '000801.XSHE',
#  '000802.XSHE',
#  '000806.XSHE',
#  '000807.XSHE',
#  '000810.XSHE',
#  '000811.XSHE',
#  '000813.XSHE',
#  '000815.XSHE',
#  '000818.XSHE',
#  '000819.XSHE',
#  '000820.XSHE',
#  '000821.XSHE',
#  '000822.XSHE',
#  '000823.XSHE',
#  '000828.XSHE',
#  '000829.XSHE',
#  '000831.XSHE',
#  '000836.XSHE',
#  '000837.XSHE',
#  '000838.XSHE',
#  '000848.XSHE',
#  '000851.XSHE',
#  '000860.XSHE',
#  '000863.XSHE',
#  '000868.XSHE',
#  '000869.XSHE',
#  '000875.XSHE',
#  '000881.XSHE',
#  '000882.XSHE',
#  '000883.XSHE',
#  '000885.XSHE',
#  '000886.XSHE',
#  '000888.XSHE',
#  '000889.XSHE',
#  '000892.XSHE',
#  '000893.XSHE',
#  '000899.XSHE',
#  '000900.XSHE',
#  '000901.XSHE',
#  '000902.XSHE',
#  '000903.XSHE',
#  '000905.XSHE',
#  '000906.XSHE',
#  '000909.XSHE',
#  '000910.XSHE',
#  '000913.XSHE',
#  '000915.XSHE',
#  '000916.XSHE',
#  '000917.XSHE',
#  '000918.XSHE',
#  '000920.XSHE',
#  '000921.XSHE',
#  '000922.XSHE',
#  '000923.XSHE',
#  '000925.XSHE',
#  '000926.XSHE',
#  '000927.XSHE',
#  '000928.XSHE',
#  '000931.XSHE',
#  '000932.XSHE',
#  '000933.XSHE',
#  '000935.XSHE',
#  '000936.XSHE',
#  '000938.XSHE',
#  '000948.XSHE',
#  '000949.XSHE',
#  '000950.XSHE',
#  '000951.XSHE',
#  '000952.XSHE',
#  '000957.XSHE',
#  '000958.XSHE',
#  '000965.XSHE',
#  '000966.XSHE',
#  '000967.XSHE',
#  '000968.XSHE',
#  '000969.XSHE',
#  '000971.XSHE',
#  '000973.XSHE',
#  '000976.XSHE',
#  '000977.XSHE',
#  '000980.XSHE',
#  '000982.XSHE',
#  '000987.XSHE',
#  '000989.XSHE',
#  '000990.XSHE',
#  '000996.XSHE',
#  '001213.XSHE',
#  '001258.XSHE',
#  '001270.XSHE',
#  '001308.XSHE',
#  '001323.XSHE',
#  '001696.XSHE',
#  '001872.XSHE',
#  '001896.XSHE',
#  '001914.XSHE',
#  '002002.XSHE',
#  '002003.XSHE',
#  '002004.XSHE',
#  '002005.XSHE',
#  '002006.XSHE',
#  '002009.XSHE',
#  '002010.XSHE',
#  '002011.XSHE',
#  '002012.XSHE',
#  '002015.XSHE',
#  '002016.XSHE',
#  '002017.XSHE',
#  '002019.XSHE',
#  '002020.XSHE',
#  '002021.XSHE',
#  '002022.XSHE',
#  '002023.XSHE',
#  '002025.XSHE',
#  '002029.XSHE',
#  '002031.XSHE',
#  '002033.XSHE',
#  '002034.XSHE',
#  '002035.XSHE',
#  '002036.XSHE',
#  '002037.XSHE',
#  '002038.XSHE',
#  '002041.XSHE',
#  '002042.XSHE',
#  '002043.XSHE',
#  '002044.XSHE',
#  '002046.XSHE',
#  '002047.XSHE',
#  '002051.XSHE',
#  '002053.XSHE',
#  '002055.XSHE',
#  '002059.XSHE',
#  '002060.XSHE',
#  '002061.XSHE',
#  '002062.XSHE',
#  '002063.XSHE',
#  '002065.XSHE',
#  '002067.XSHE',
#  '002068.XSHE',
#  '002070.XSHE',
#  '002071.XSHE',
#  '002073.XSHE',
#  '002074.XSHE',
#  '002075.XSHE',
#  '002079.XSHE',
#  '002080.XSHE',
#  '002083.XSHE',
#  '002085.XSHE',
#  '002086.XSHE',
#  '002088.XSHE',
#  '002089.XSHE',
#  '002090.XSHE',
#  '002091.XSHE',
#  '002094.XSHE',
#  '002095.XSHE',
#  '002096.XSHE',
#  '002097.XSHE',
#  '002099.XSHE',
#  '002100.XSHE',
#  '002101.XSHE',
#  '002102.XSHE',
#  '002103.XSHE',
#  '002104.XSHE',
#  '002106.XSHE',
#  '002107.XSHE',
#  '002108.XSHE',
#  '002110.XSHE',
#  '002111.XSHE',
#  '002113.XSHE',
#  '002114.XSHE',
#  '002115.XSHE',
#  '002116.XSHE',
#  '002117.XSHE',
#  '002121.XSHE',
#  '002123.XSHE',
#  '002124.XSHE',
#  '002126.XSHE',
#  '002130.XSHE',
#  '002131.XSHE',
#  '002135.XSHE',
#  '002137.XSHE',
#  '002138.XSHE',
#  '002139.XSHE',
#  '002141.XSHE',
#  '002143.XSHE',
#  '002144.XSHE',
#  '002145.XSHE',
#  '002147.XSHE',
#  '002148.XSHE',
#  '002151.XSHE',
#  '002154.XSHE',
#  '002156.XSHE',
#  '002157.XSHE',
#  '002158.XSHE',
#  '002161.XSHE',
#  '002162.XSHE',
#  '002163.XSHE',
#  '002165.XSHE',
#  '002166.XSHE',
#  '002167.XSHE',
#  '002168.XSHE',
#  '002170.XSHE',
#  '002171.XSHE',
#  '002172.XSHE',
#  '002174.XSHE',
#  '002175.XSHE',
#  '002176.XSHE',
#  '002177.XSHE',
#  '002178.XSHE',
#  '002180.XSHE',
#  '002181.XSHE',
#  '002182.XSHE',
#  '002184.XSHE',
#  '002185.XSHE',
#  '002188.XSHE',
#  '002190.XSHE',
#  '002192.XSHE',
#  '002194.XSHE',
#  '002196.XSHE',
#  '002197.XSHE',
#  '002198.XSHE',
#  '002201.XSHE',
#  '002203.XSHE',
#  '002204.XSHE',
#  '002206.XSHE',
#  '002207.XSHE',
#  '002210.XSHE',
#  '002212.XSHE',
#  '002214.XSHE',
#  '002215.XSHE',
#  '002216.XSHE',
#  '002217.XSHE',
#  '002218.XSHE',
#  '002219.XSHE',
#  '002222.XSHE',
#  '002224.XSHE',
#  '002225.XSHE',
#  '002226.XSHE',
#  '002227.XSHE',
#  '002228.XSHE',
#  '002229.XSHE',
#  '002231.XSHE',
#  '002232.XSHE',
#  '002233.XSHE',
#  '002234.XSHE',
#  '002235.XSHE',
#  '002237.XSHE',
#  '002239.XSHE',
#  '002240.XSHE',
#  '002243.XSHE',
#  '002245.XSHE',
#  '002246.XSHE',
#  '002247.XSHE',
#  '002251.XSHE',
#  '002253.XSHE',
#  '002254.XSHE',
#  '002255.XSHE',
#  '002256.XSHE',
#  '002258.XSHE',
#  '002259.XSHE',
#  '002260.XSHE',
#  '002261.XSHE',
#  '002262.XSHE',
#  '002263.XSHE',
#  '002267.XSHE',
#  '002268.XSHE',
#  '002270.XSHE',
#  '002274.XSHE',
#  '002276.XSHE',
#  '002277.XSHE',
#  '002279.XSHE',
#  '002283.XSHE',
#  '002284.XSHE',
#  '002285.XSHE',
#  '002287.XSHE',
#  '002288.XSHE',
#  '002289.XSHE',
#  '002291.XSHE',
#  '002292.XSHE',
#  '002293.XSHE',
#  '002296.XSHE',
#  '002297.XSHE',
#  '002298.XSHE',
#  '002301.XSHE',
#  '002302.XSHE',
#  '002303.XSHE',
#  '002305.XSHE',
#  '002307.XSHE',
#  '002308.XSHE',
#  '002309.XSHE',
#  '002310.XSHE',
#  '002312.XSHE',
#  '002313.XSHE',
#  '002314.XSHE',
#  '002317.XSHE',
#  '002318.XSHE',
#  '002320.XSHE',
#  '002321.XSHE',
#  '002322.XSHE',
#  '002323.XSHE',
#  '002324.XSHE',
#  '002326.XSHE',
#  '002327.XSHE',
#  '002328.XSHE',
#  '002329.XSHE',
#  '002331.XSHE',
#  '002332.XSHE',
#  '002334.XSHE',
#  '002335.XSHE',
#  '002337.XSHE',
#  '002338.XSHE',
#  '002339.XSHE',
#  '002341.XSHE',
#  '002343.XSHE',
#  '002344.XSHE',
#  '002345.XSHE',
#  '002346.XSHE',
#  '002348.XSHE',
#  '002349.XSHE',
#  '002351.XSHE',
#  '002355.XSHE',
#  '002356.XSHE',
#  '002358.XSHE',
#  '002359.XSHE',
#  '002362.XSHE',
#  '002363.XSHE',
#  '002364.XSHE',
#  '002366.XSHE',
#  '002367.XSHE',
#  '002369.XSHE',
#  '002370.XSHE',
#  '002372.XSHE',
#  '002376.XSHE',
#  '002377.XSHE',
#  '002378.XSHE',
#  '002379.XSHE',
#  '002380.XSHE',
#  '002381.XSHE',
#  '002382.XSHE',
#  '002383.XSHE',
#  '002386.XSHE',
#  '002387.XSHE',
#  '002388.XSHE',
#  '002389.XSHE',
#  '002390.XSHE',
#  '002391.XSHE',
#  '002393.XSHE',
#  '002394.XSHE',
#  '002396.XSHE',
#  '002398.XSHE',
#  '002400.XSHE',
#  '002401.XSHE',
#  '002402.XSHE',
#  '002405.XSHE',
#  '002406.XSHE',
#  '002407.XSHE',
#  '002409.XSHE',
#  '002411.XSHE',
#  '002413.XSHE',
#  '002416.XSHE',
#  '002418.XSHE',
#  '002419.XSHE',
#  '002421.XSHE',
#  '002425.XSHE',
#  '002426.XSHE',
#  '002427.XSHE',
#  '002428.XSHE',
#  '002429.XSHE',
#  '002430.XSHE',
#  '002432.XSHE',
#  '002433.XSHE',
#  '002434.XSHE',
#  '002435.XSHE',
#  '002436.XSHE',
#  '002437.XSHE',
#  '002438.XSHE',
#  '002440.XSHE',
#  '002441.XSHE',
#  '002443.XSHE',
#  '002445.XSHE',
#  '002446.XSHE',
#  '002447.XSHE',
#  '002448.XSHE',
#  '002449.XSHE',
#  '002451.XSHE',
#  '002452.XSHE',
#  '002453.XSHE',
#  '002454.XSHE',
#  '002456.XSHE',
#  '002457.XSHE',
#  '002458.XSHE',
#  '002459.XSHE',
#  '002460.XSHE',
#  '002461.XSHE',
#  '002462.XSHE',
#  '002463.XSHE',
#  '002464.XSHE',
#  '002467.XSHE',
#  '002468.XSHE',
#  '002469.XSHE',
#  '002471.XSHE',
#  '002472.XSHE',
#  '002474.XSHE',
#  '002476.XSHE',
#  '002478.XSHE',
#  '002479.XSHE',
#  '002481.XSHE',
#  '002482.XSHE',
#  '002483.XSHE',
#  '002484.XSHE',
#  '002485.XSHE',
#  '002486.XSHE',
#  '002487.XSHE',
#  '002488.XSHE',
#  '002489.XSHE',
#  '002491.XSHE',
#  '002494.XSHE',
#  '002496.XSHE',
#  '002497.XSHE',
#  '002498.XSHE',
#  '002499.XSHE',
#  '002501.XSHE',
#  '002502.XSHE',
#  '002504.XSHE',
#  '002507.XSHE',
#  '002509.XSHE',
#  '002510.XSHE',
#  '002511.XSHE',
#  '002512.XSHE',
#  '002515.XSHE',
#  '002516.XSHE',
#  '002517.XSHE',
#  '002518.XSHE',
#  '002519.XSHE',
#  '002520.XSHE',
#  '002521.XSHE',
#  '002522.XSHE',
#  '002524.XSHE',
#  '002526.XSHE',
#  '002527.XSHE',
#  '002528.XSHE',
#  '002529.XSHE',
#  '002530.XSHE',
#  '002531.XSHE',
#  '002532.XSHE',
#  '002534.XSHE',
#  '002535.XSHE',
#  '002537.XSHE',
#  '002538.XSHE',
#  '002539.XSHE',
#  '002540.XSHE',
#  '002541.XSHE',
#  '002542.XSHE',
#  '002543.XSHE',
#  '002544.XSHE',
#  '002545.XSHE',
#  '002546.XSHE',
#  '002547.XSHE',
#  '002549.XSHE',
#  '002550.XSHE',
#  '002554.XSHE',
#  '002555.XSHE',
#  '002556.XSHE',
#  '002557.XSHE',
#  '002558.XSHE',
#  '002559.XSHE',
#  '002561.XSHE',
#  '002562.XSHE',
#  '002564.XSHE',
#  '002565.XSHE',
#  '002566.XSHE',
#  '002567.XSHE',
#  '002568.XSHE',
#  '002570.XSHE',
#  '002571.XSHE',
#  '002572.XSHE',
#  '002573.XSHE',
#  '002574.XSHE',
#  '002575.XSHE',
#  '002577.XSHE',
#  '002579.XSHE',
#  '002581.XSHE',
#  '002582.XSHE',
#  '002583.XSHE',
#  '002584.XSHE',
#  '002585.XSHE',
#  '002586.XSHE',
#  '002589.XSHE',
#  '002590.XSHE',
#  '002592.XSHE',
#  '002596.XSHE',
#  '002597.XSHE',
#  '002600.XSHE',
#  '002601.XSHE',
#  '002602.XSHE',
#  '002604.XSHE',
#  '002605.XSHE',
#  '002606.XSHE',
#  '002609.XSHE',
#  '002610.XSHE',
#  '002611.XSHE',
#  '002612.XSHE',
#  '002613.XSHE',
#  '002614.XSHE',
#  '002616.XSHE',
#  '002617.XSHE',
#  '002618.XSHE',
#  '002619.XSHE',
#  '002621.XSHE',
#  '002622.XSHE',
#  '002625.XSHE',
#  '002626.XSHE',
#  '002628.XSHE',
#  '002630.XSHE',
#  '002631.XSHE',
#  '002635.XSHE',
#  '002636.XSHE',
#  '002638.XSHE',
#  '002639.XSHE',
#  '002640.XSHE',
#  '002641.XSHE',
#  '002643.XSHE',
#  '002644.XSHE',
#  '002645.XSHE',
#  '002646.XSHE',
#  '002647.XSHE',
#  '002648.XSHE',
#  '002649.XSHE',
#  '002650.XSHE',
#  '002651.XSHE',
#  '002653.XSHE',
#  '002655.XSHE',
#  '002656.XSHE',
#  '002657.XSHE',
#  '002658.XSHE',
#  '002660.XSHE',
#  '002662.XSHE',
#  '002663.XSHE',
#  '002664.XSHE',
#  '002666.XSHE',
#  '002667.XSHE',
#  '002668.XSHE',
#  '002670.XSHE',
#  '002671.XSHE',
#  '002672.XSHE',
#  '002675.XSHE',
#  '002677.XSHE',
#  '002678.XSHE',
#  '002680.XSHE',
#  '002683.XSHE',
#  '002684.XSHE',
#  '002685.XSHE',
#  '002689.XSHE',
#  '002693.XSHE',
#  '002695.XSHE',
#  '002697.XSHE',
#  '002698.XSHE',
#  '002699.XSHE',
#  '002700.XSHE',
#  '002703.XSHE',
#  '002705.XSHE',
#  '002706.XSHE',
#  '002707.XSHE',
#  '002709.XSHE',
#  '002711.XSHE',
#  '002712.XSHE',
#  '002713.XSHE',
#  '002716.XSHE',
#  '002717.XSHE',
#  '002721.XSHE',
#  '002724.XSHE',
#  '002726.XSHE',
#  '002727.XSHE',
#  '002731.XSHE',
#  '002733.XSHE',
#  '002737.XSHE',
#  '002738.XSHE',
#  '002741.XSHE',
#  '002742.XSHE',
#  '002746.XSHE',
#  '002747.XSHE',
#  '002750.XSHE',
#  '002751.XSHE',
#  '002752.XSHE',
#  '002755.XSHE',
#  '002756.XSHE',
#  '002759.XSHE',
#  '002761.XSHE',
#  '002762.XSHE',
#  '002763.XSHE',
#  '002766.XSHE',
#  '002768.XSHE',
#  '002769.XSHE',
#  '002771.XSHE',
#  '002772.XSHE',
#  '002773.XSHE',
#  '002776.XSHE',
#  '002777.XSHE',
#  '002781.XSHE',
#  '002782.XSHE',
#  '002783.XSHE',
#  '002786.XSHE',
#  '002788.XSHE',
#  '002790.XSHE',
#  '002791.XSHE',
#  '002792.XSHE',
#  '002793.XSHE',
#  '002796.XSHE',
#  '002798.XSHE',
#  '002801.XSHE',
#  '002802.XSHE',
#  '002803.XSHE',
#  '002807.XSHE',
#  '002810.XSHE',
#  '002812.XSHE',
#  '002815.XSHE',
#  '002821.XSHE',
#  '002822.XSHE',
#  '002832.XSHE',
#  '002833.XSHE',
#  '002837.XSHE',
#  '002838.XSHE',
#  '002839.XSHE',
#  '002840.XSHE',
#  '002847.XSHE',
#  '002850.XSHE',
#  '002851.XSHE',
#  '002852.XSHE',
#  '002859.XSHE',
#  '002865.XSHE',
#  '002867.XSHE',
#  '002869.XSHE',
#  '002872.XSHE',
#  '002880.XSHE',
#  '002891.XSHE',
#  '002895.XSHE',
#  '002901.XSHE',
#  '002906.XSHE',
#  '002907.XSHE',
#  '002911.XSHE',
#  '002912.XSHE',
#  '002913.XSHE',
#  '002918.XSHE',
#  '002920.XSHE',
#  '002928.XSHE',
#  '002929.XSHE',
#  '002930.XSHE',
#  '002933.XSHE',
#  '002941.XSHE',
#  '002946.XSHE',
#  '002947.XSHE',
#  '002950.XSHE',
#  '002951.XSHE',
#  '002955.XSHE',
#  '002959.XSHE',
#  '002960.XSHE',
#  '002961.XSHE',
#  '002962.XSHE',
#  '002967.XSHE',
#  '002969.XSHE',
#  '002970.XSHE',
#  '002973.XSHE',
#  '002975.XSHE',
#  '002977.XSHE',
#  '002978.XSHE',
#  '002979.XSHE',
#  '002980.XSHE',
#  '002982.XSHE',
#  '002984.XSHE',
#  '002987.XSHE',
#  '002989.XSHE',
#  '002990.XSHE',
#  '002991.XSHE',
#  '002993.XSHE',
#  '003006.XSHE',
#  '003009.XSHE',
#  '003012.XSHE',
#  '003021.XSHE',
#  '003031.XSHE',
#  '003032.XSHE',
#  '003039.XSHE',
#  '003040.XSHE',
#  '300001.XSHE',
#  '300004.XSHE',
#  '300005.XSHE',
#  '300006.XSHE',
#  '300007.XSHE',
#  '300008.XSHE',
#  '300009.XSHE',
#  '300010.XSHE',
#  '300011.XSHE',
#  '300012.XSHE',
#  '300014.XSHE',
#  '300016.XSHE',
#  '300018.XSHE',
#  '300020.XSHE',
#  '300021.XSHE',
#  '300025.XSHE',
#  '300027.XSHE',
#  '300028.XSHE',
#  '300030.XSHE',
#  '300031.XSHE',
#  '300032.XSHE',
#  '300034.XSHE',
#  '300035.XSHE',
#  '300036.XSHE',
#  '300037.XSHE',
#  '300038.XSHE',
#  '300039.XSHE',
#  '300041.XSHE',
#  '300043.XSHE',
#  '300044.XSHE',
#  '300045.XSHE',
#  '300047.XSHE',
#  '300048.XSHE',
#  '300049.XSHE',
#  '300050.XSHE',
#  '300051.XSHE',
#  '300052.XSHE',
#  '300053.XSHE',
#  '300054.XSHE',
#  '300055.XSHE',
#  '300056.XSHE',
#  '300057.XSHE',
#  '300061.XSHE',
#  '300063.XSHE',
#  '300064.XSHE',
#  '300065.XSHE',
#  '300066.XSHE',
#  '300067.XSHE',
#  '300068.XSHE',
#  '300071.XSHE',
#  '300073.XSHE',
#  '300074.XSHE',
#  '300075.XSHE',
#  '300076.XSHE',
#  '300077.XSHE',
#  '300078.XSHE',
#  '300079.XSHE',
#  '300080.XSHE',
#  '300081.XSHE',
#  '300082.XSHE',
#  '300083.XSHE',
#  '300084.XSHE',
#  '300085.XSHE',
#  '300086.XSHE',
#  '300087.XSHE',
#  '300090.XSHE',
#  '300091.XSHE',
#  '300096.XSHE',
#  '300097.XSHE',
#  '300098.XSHE',
#  '300100.XSHE',
#  '300101.XSHE',
#  '300102.XSHE',
#  '300103.XSHE',
#  '300105.XSHE',
#  '300107.XSHE',
#  '300109.XSHE',
#  '300110.XSHE',
#  '300111.XSHE',
#  '300113.XSHE',
#  '300114.XSHE',
#  '300118.XSHE',
#  '300119.XSHE',
#  '300123.XSHE',
#  '300127.XSHE',
#  '300128.XSHE',
#  '300129.XSHE',
#  '300130.XSHE',
#  '300131.XSHE',
#  '300132.XSHE',
#  '300133.XSHE',
#  '300134.XSHE',
#  '300135.XSHE',
#  '300136.XSHE',
#  '300137.XSHE',
#  '300139.XSHE',
#  '300140.XSHE',
#  '300142.XSHE',
#  '300143.XSHE',
#  '300145.XSHE',
#  '300148.XSHE',
#  '300149.XSHE',
#  '300150.XSHE',
#  '300151.XSHE',
#  '300152.XSHE',
#  '300155.XSHE',
#  '300156.XSHE',
#  '300157.XSHE',
#  '300158.XSHE',
#  '300159.XSHE',
#  '300160.XSHE',
#  '300162.XSHE',
#  '300164.XSHE',
#  '300165.XSHE',
#  '300166.XSHE',
#  '300168.XSHE',
#  '300170.XSHE',
#  '300171.XSHE',
#  '300172.XSHE',
#  '300173.XSHE',
#  '300175.XSHE',
#  '300176.XSHE',
#  '300177.XSHE',
#  '300178.XSHE',
#  '300180.XSHE',
#  '300181.XSHE',
#  '300183.XSHE',
#  '300184.XSHE',
#  '300185.XSHE',
#  '300187.XSHE',
#  '300188.XSHE',
#  '300190.XSHE',
#  '300191.XSHE',
#  '300193.XSHE',
#  '300194.XSHE',
#  '300195.XSHE',
#  '300197.XSHE',
#  '300198.XSHE',
#  '300200.XSHE',
#  '300203.XSHE',
#  '300204.XSHE',
#  '300205.XSHE',
#  '300206.XSHE',
#  ...]

# %%
Index_turnover = pd.concat([
    (xy.turns*xy.weights50).dropna(how='all',axis=1).sum().rename('50'),
    (xy.turns*xy.weights300).dropna(how='all',axis=1).sum().rename('300'),
    (xy.turns*xy.weights500).dropna(how='all',axis=1).sum().rename('500'),
    (xy.turns*xy.weights1000).dropna(how='all',axis=1).sum().rename('1000')
],axis=1).shift(1).T

# %%
Index_OrgMom = pd.concat([
    (Orig_Mom*xy.weights50).dropna(how='all',axis=1).sum().rename('50'),
    (Orig_Mom*xy.weights300).dropna(how='all',axis=1).sum().rename('300'),
    (Orig_Mom*xy.weights500).dropna(how='all',axis=1).sum().rename('500'),
    (Orig_Mom*xy.weights1000).dropna(how='all',axis=1).sum().rename('1000')
],axis=1).T

# %%
def get_ovn_money_mom(ser):
    # 隔夜成交量,昨日最后5分钟量
    fore_ovn_money = pd.Series(np.nansum(xy.rolling_window(ser.money,5)[235::240],axis=1),ser[::240].index.map(lambda x: str(x)[:10]))

    # 隔夜动量
    open1min50 = ser[::240].open
    close1min50 = ser[239::240].close
    
    open1min50.index = open1min50.index.map(lambda x:str(x)[:10])
    close1min50.index = close1min50.index.map(lambda x:str(x)[:10])
    
    ovn_mom = (open1min50/close1min50.shift(1) - 1)
    
    return fore_ovn_money, ovn_mom

# %%
def tov_rank(x):
    xrk = x.rank()
    return list(xrk)

# %%
def inraday_mom(
    idx_name,
    Index_turnover,
    ret,
    winsize
):
    TRs1 = []
    TRs2 = []
    TRs3 = []
    TRs4 = []
    TRs5 = []
    dts = []
    for _, win in enumerate(Index_turnover.T[idx_name].rolling(winsize,min_periods=winsize)):
        if _ < winsize-1:
            # print(_)
            continue

        rk = win.rank()
        rt = ret.T[idx_name][_-winsize+1:_+1]
        TRs1.append(rt[rk < (winsize/5)+1].mean())
        TRs2.append(rt[(rk >= (winsize/5)+1)&(rk < 2*(winsize/5)+1)].mean())
        TRs3.append(rt[(rk >= 2*(winsize/5)+1)&(rk < 3*(winsize/5)+1)].mean())
        TRs4.append(rt[(rk >= 3*(winsize/5)+1)&(rk < 4*(winsize/5)+1)].mean())
        TRs5.append(rt[rk >= 4*(winsize/5)+1].mean())
        dts.append(rt.index[-1])
        
    return pd.Series(TRs1,dts),pd.Series(TRs2,dts),pd.Series(TRs3,dts),pd.Series(TRs4,dts),pd.Series(TRs5,dts)

# %%
def inraday_mom_all1(
    tov,
    winsize=20
):
    TRs1 = []
    dts = []
    for _, win in enumerate(tov.rolling(winsize,min_periods=winsize)):
        if _ < winsize-1:
            # print(_)
            continue

        rk = win.rank()
        rt = xy.ret[_-winsize+1:_+1]
        TRs1.append(rt[rk < (winsize/5)+1].mean())
        dts.append(rt.index[-1])
        
    return pd.Series(TRs1,dts)

def inraday_mom_all5(
    tov,
    winsize
):
    TRs5 = []
    dts = []
    for _, win in enumerate(tov.rolling(winsize,min_periods=winsize)):
        if _ < winsize-1:
            # print(_)
            continue

        rk = win.rank()
        rt = xy.ret[_-winsize+1:_+1]
        TRs5.append(rt[rk > 4*(winsize/5)+1].mean())
        dts.append(rt.index[-1])
        
    return pd.Series(TRs5,dts)

# %%
trs50_1,trs50_2,trs50_3,trs50_4,trs50_5 = inraday_mom('50',Index_turnover,xy.Index_rets,20)
trs300_1,trs300_2,trs300_3,trs300_4,trs300_5 = inraday_mom('300',Index_turnover,xy.Index_rets,20)
trs500_1,trs500_2,trs500_3,trs500_4,trs500_5 = inraday_mom('500',Index_turnover,xy.Index_rets,20)
trs1000_1,trs1000_2,trs1000_3,trs1000_4,trs1000_5 = inraday_mom('1000',Index_turnover,xy.Index_rets,20)

# %%
TSR5 = pd.concat([
    trs50_5.rename('50'),
    trs300_5.rename('300'),
    trs500_5.rename('500'),
    trs1000_5.rename('1000')
],axis=1).T

TSR1 = pd.concat([
    trs50_1.rename('50'),
    trs300_1.rename('300'),
    trs500_1.rename('500'),
    trs1000_1.rename('1000')
],axis=1).T

New_TSR = (TSR5 - TSR5.mean())/TSR5.std() - (TSR1 - TSR1.mean())/TSR1.std()

# %% [markdown]
# ### 隔夜动量

# %% [markdown]
# #### 计算

# %%
fore_ovn_money50, ovn_mom50 = get_ovn_money_mom(xy.IndexMin50jq)
fore_ovn_money300, ovn_mom300 = get_ovn_money_mom(xy.IndexMin300jq)
fore_ovn_money500, ovn_mom500 = get_ovn_money_mom(xy.IndexMin500jq)
fore_ovn_money1000, ovn_mom1000 = get_ovn_money_mom(xy.IndexMin1000jq)

# %%
fore_ovn_money
# Out:
#       2009-01-05    2009-01-06    2009-01-07    2009-01-08    2009-01-09  \
# 50           NaN  8.250600e+08  8.135700e+08  7.307400e+08  6.344200e+08
# 300          NaN  1.828710e+09  2.013940e+09  1.861210e+09  1.489030e+09
# 500          NaN  7.935900e+08  9.751000e+08  9.623200e+08  8.130200e+08
# 1000         NaN  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#         2009-01-12    2009-01-13    2009-01-14    2009-01-15    2009-01-16  \
# 50    6.769100e+08  5.158634e+08  4.247900e+08  1.107980e+09  6.541400e+08
# 300   1.728810e+09  1.483170e+09  1.355240e+09  2.623140e+09  1.991300e+09
# 500   9.227900e+08  8.786500e+08  8.295500e+08  1.235610e+09  1.157390e+09
# 1000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#       ...    2023-05-10    2023-05-11    2023-05-12    2023-05-15  \
# 50    ...  1.991171e+09  1.458768e+09  1.271485e+09  1.599953e+09
# 300   ...  7.481325e+09  6.114054e+09  5.458529e+09  6.106284e+09
# 500   ...  4.312992e+09  3.974655e+09  3.701919e+09  4.238894e+09
# 1000  ...  5.445847e+09  4.811376e+09  4.712436e+09  4.915385e+09
#
#         2023-05-16    2023-05-17    2023-05-18    2023-05-19    2023-05-22  \
# 50    1.657399e+09  1.008896e+09  1.180294e+09  1.028243e+09  1.299600e+09
# 300   6.045430e+09  4.686187e+09  5.080390e+09  5.039014e+09  5.276711e+09
# 500   3.918296e+09  3.400174e+09  3.324875e+09  3.491412e+09  3.938973e+09
# 1000  4.815079e+09  4.122559e+09  4.339571e+09  4.773196e+09  4.808558e+09
#
#         2023-05-23
# 50    1.248882e+09
# 300   4.504931e+09
# 500   3.235583e+09
# 1000  4.283948e+09
#
# [4 rows x 3495 columns]

# %%
fore_ovn_money = pd.concat([
    fore_ovn_money50.rename('50'),
    fore_ovn_money300.rename('300'),
    fore_ovn_money500.rename('500'),
    fore_ovn_money1000.rename('1000')
],axis=1).shift(1).T

# %%
fore_ovn_mom
# Out:
#       2009-01-05  2009-01-06  2009-01-07  2009-01-08  2009-01-09  2009-01-12  \
# 50           NaN   -0.005297         0.0   -0.014508   -0.003198   -0.005258
# 300          NaN         NaN         NaN         NaN         NaN         NaN
# 500          NaN         NaN         NaN         NaN         NaN         NaN
# 1000         NaN         NaN         NaN         NaN         NaN         NaN
#
#       2009-01-13  2009-01-14  2009-01-15  2009-01-16  ...  2023-05-10  \
# 50     -0.011628         0.0   -0.012333    0.003112  ...   -0.001478
# 300          NaN         NaN         NaN         NaN  ...   -0.000498
# 500          NaN         NaN         NaN         NaN  ...   -0.000322
# 1000         NaN         NaN         NaN         NaN  ...   -0.001894
#
#       2023-05-11  2023-05-12  2023-05-15  2023-05-16  2023-05-17  2023-05-18  \
# 50      0.003366   -0.001124   -0.000380    0.000746   -0.001122    0.002265
# 300     0.002508   -0.000251    0.000509   -0.000250   -0.001760    0.001772
# 500     0.000969   -0.000972   -0.000818    0.000000   -0.002443    0.001791
# 1000    0.000756   -0.002270    0.000000    0.000381    0.000000   -0.000764
#
#       2023-05-19  2023-05-22  2023-05-23
# 50     -0.003025   -0.000759    0.001504
# 300    -0.002532   -0.000254    0.000757
# 500    -0.001300   -0.000162    0.000000
# 1000   -0.000761   -0.001515    0.000759
#
# [4 rows x 3495 columns]

# %%
fore_ovn_mom = pd.concat([
    ovn_mom50.rename('50'),
    ovn_mom300.rename('300'),
    ovn_mom500.rename('500'),
    ovn_mom1000.rename('1000')
],axis=1).T

# %%
ovn_trs50_1,ovn_trs50_2,ovn_trs50_3,ovn_trs50_4,ovn_trs50_5 = inraday_mom('50',fore_ovn_money,fore_ovn_mom,20)
ovn_trs300_1,ovn_trs300_2,ovn_trs300_3,ovn_trs300_4,ovn_trs300_5 = inraday_mom('300',fore_ovn_money,fore_ovn_mom,20)
ovn_trs500_1,ovn_trs500_2,ovn_trs500_3,ovn_trs500_4,ovn_trs500_5 = inraday_mom('500',fore_ovn_money,fore_ovn_mom,20)
ovn_trs1000_1,ovn_trs1000_2,ovn_trs1000_3,ovn_trs1000_4,ovn_trs1000_5 = inraday_mom('1000',fore_ovn_money,fore_ovn_mom,20)

# %%
ovn_TSR5 = pd.concat([
    ovn_trs50_5.rename('50'),
    ovn_trs300_5.rename('300'),
    ovn_trs500_5.rename('500'),
    ovn_trs1000_5.rename('1000')
],axis=1).shift(1).T

ovn_TSR1 = pd.concat([
    ovn_trs50_1.rename('50'),
    ovn_trs300_1.rename('300'),
    ovn_trs500_1.rename('500'),
    ovn_trs1000_1.rename('1000')
],axis=1).shift(1).T

New_ovn_TSR = (ovn_TSR5 - ovn_TSR5.mean())/ovn_TSR5.std() - (ovn_TSR1 - ovn_TSR1.mean())/ovn_TSR1.std()

# %%
# 分组收益率
xy.cal_rate_group(
    New_ovn_TSR,
    xy.Index_rets,
    group_num=4,
    masks=1
).cumsum().plot()
# Out:
# -8.770686894034968e-05
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %% [markdown]
# #### 多头

# %%
idx_name = '50'
for i in range(15)[::2]:
    i = i / 10
    same_dt = set(xy.Index_rets.T[idx_name].index) & set(New_TSR1_idx.T[idx_name].dropna().index)
    ts_ret = xy.Index_rets.T[idx_name].loc[New_TSR1_idx.T[idx_name][New_TSR1_idx.T[idx_name]>i].index&same_dt]
    
    if len(ts_ret) < 1:
        continue
        
    # if i < 1.4:
    #     continue

    win_pct = ts_ret[ts_ret>0].shape[0]/ts_ret.shape[0]
    win_loss_ratio = ts_ret[ts_ret>0].mean()/ts_ret[ts_ret<0].mean()
    
    print('shrh:',i, 'win%:', win_pct,'gainloss%:', win_loss_ratio)
    
    pd.Series(ts_ret.cumsum().rename(i),xy.Index_rets.T[idx_name].index).ffill().plot(legend=True,figsize=(15,8))
    
    if i == 0.8:
        break
# Out:
# shrh: 0.0 win%: 0.5179934569247546 gainloss%: -1.0500771309914925
# shrh: 0.2 win%: 0.5184331797235023 gainloss%: -1.0457987586226194
# shrh: 0.4 win%: 0.5264452644526445 gainloss%: -1.0940243752413124
# shrh: 0.6 win%: 0.5328947368421053 gainloss%: -1.0777997288470291
# shrh: 0.8 win%: 0.524024024024024 gainloss%: -1.0639112829064319

# %%
ts_ret[ts_ret/ts_ret.shift()<0]
# Out:
# 2016-01-05    0.007775
# 2016-01-07   -0.059137
# 2016-01-08    0.017896
# 2016-01-11   -0.044773
# 2016-01-12    0.005251
#                 ...
# 2022-12-07   -0.005288
# 2022-12-08    0.000842
# 2022-12-12   -0.012118
# 2022-12-13    0.001107
# 2022-12-19   -0.015665
# Name: 50, Length: 406, dtype: float64

# %% [markdown]
# #### 空头

# %%
idx_name = '50'
for i in range(15)[::2]:
    i = i / 10
    same_dt = set(xy.Index_rets.T[idx_name].index) & set(New_TSR1_idx.T[idx_name].dropna().index)
    ts_ret = xy.Index_rets.T[idx_name].loc[New_TSR1_idx.T[idx_name][New_TSR1_idx.T[idx_name]<-i].index&same_dt]
    
    if len(ts_ret) < 1:
        continue
    
    
        
    win_pct = ts_ret[ts_ret>0].shape[0]/ts_ret.shape[0]
    win_loss_ratio = ts_ret[ts_ret>0].mean()/ts_ret[ts_ret<0].mean()
    print('shrh:',i, 'win%:', win_pct,'gainloss%:', win_loss_ratio)
    pd.Series(ts_ret.cumsum().rename(i), xy.Index_rets.T[idx_name].index).ffill().plot(legend=True,figsize=(15,8))
    
    if i == 0.6:
        break
# Out:
# shrh: 0.0 win%: 0.4976958525345622 gainloss%: -0.9456345567608521
# shrh: 0.2 win%: 0.5036585365853659 gainloss%: -0.9324467286715544
# shrh: 0.4 win%: 0.5065274151436031 gainloss%: -0.9112198314775933
# shrh: 0.6 win%: 0.504297994269341 gainloss%: -0.9124547541108481

# %%
ts_ret[ts_ret/ts_ret.shift()<0]
# Out:
# 2016-03-11    0.004498
# 2016-03-17   -0.002175
# 2016-05-12    0.003092
# 2016-05-13   -0.004149
# 2016-08-02    0.000417
#                 ...
# 2023-04-19   -0.008649
# 2023-04-25    0.000288
# 2023-04-26   -0.000479
# 2023-04-27    0.012449
# 2023-05-05   -0.002792
# Name: 50, Length: 372, dtype: float64

# %% [markdown]
# ## 评估

# %% [markdown]
# ### cl-cl

# %%
# 分组收益率
gr_ENPchange = xy.cal_rate_group(
    New_TSR,
    xy.Index_rets,
    group_num=4,
    masks=1
)
gr_ENPchange.cumsum().plot()
# Out:
# -0.005304542389488867
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %%
# 单因子强弱
ENPchange_select, ENPchange_rets = xy.single_Factor_backtest(
    New_TSR1_idx,
    xy.Index_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    _side=1,
    fee=0.000,
    name='ENPchange'
)
# Out:
# 1200.0
# yoy: 0.13930217658595143
#  mdd: -0.24263911959858697
#  sharpe: 0.8083180496890677
#  rankIC: 0.046514285714285716
#  rankIR: 0.060718360034692116
#  win%: 0.519327731092437
#  gain_loss%: -1.0222420349084191

# %%
# 因子截面IC趋势
rankIC = xy.Index_rets.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False).corrwith(New_TSR1_idx.rank(ascending=False))
rankIC.rolling(60).mean().plot(figsize=(15,8),grid=1)
rankIC.mean()
# Out:
# 0.046514285714285716

# %% [markdown]
# ### cl_op

# %%
# 分组收益率
gr_ENPchange = xy.cal_rate_group(
    New_TSR1_idx.T.rolling(1).mean().T.loc[['50', '300', '500', '1000'],'2016-02-28':],
    xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    group_num=4,
    masks=1
)
gr_ENPchange.cumsum().plot()
# Out:
# -0.05012971921705416
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %%
# 单因子强弱
ENPchange_select, ENPchange_rets = xy.single_Factor_backtest(
    New_TSR1_idx.T.rolling(1).mean().T.loc[['50', '300', '500', '1000'],'2016-02-28':],
    xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    _side=1,
    fee=0.000,
    name='ENPchange'
)
# Out:
# 1196.0
# yoy: -0.037091003278173745
#  mdd: -0.31745989490437765
#  sharpe: -0.772221553049972
#  rankIC: -0.03474285714285715
#  rankIR: -0.0476398609918534
#  win%: 0.47314285714285714
#  gain_loss%: -0.9572870637371589

# %%
# 因子截面IC趋势
rankIC = xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False).corrwith(New_TSR1_idx.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False))
rankIC.rolling(60).mean().plot(figsize=(15,8),grid=1)
rankIC.mean()
# Out:
# -0.03474285714285715

# %% [markdown]
# ### 择时

# %%
New_TSR
# Out:
#       2016-01-29  2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# 50      0.147235    0.226462    1.930968    1.764611    1.508440    1.616129
# 300    -0.350651   -0.180354    1.422594    1.234912    1.238376    1.420999
# 500     0.305772   -0.170631   -1.830181   -0.871996   -0.627495   -0.971579
# 1000   -0.102355    0.124523   -1.523380   -2.127528   -2.119321   -2.065549
#
#       2016-02-15  2016-02-16  2016-02-17  2016-02-18  ...  2023-04-21  \
# 50      1.754330    1.857371    1.925839    1.925839  ...   -0.373158
# 300     1.132818    0.808581    0.548959    0.548959  ...    0.329314
# 500    -0.864574   -2.158523   -2.045980   -2.045980  ...    0.521820
# 1000   -2.022574   -0.507429   -0.428817   -0.428817  ...   -0.477975
#
#       2023-04-24  2023-04-25  2023-04-26  2023-04-27  2023-04-28  2023-05-04  \
# 50      0.157809   -0.898556   -0.218572    0.507251    1.803494    2.533228
# 300    -0.386280   -0.323111    0.273875   -1.049272   -1.349483   -1.132364
# 500     0.278926    1.243249   -0.667052    0.253414   -0.787568   -1.161915
# 1000   -0.050455   -0.021582    0.611749    0.288606    0.333557   -0.238948
#
#       2023-05-05  2023-05-08  2023-05-09
# 50      2.403438    2.283654    2.237313
# 300    -2.331592   -2.250266   -2.602437
# 500    -0.249733   -0.459283    0.304789
# 1000    0.177887    0.425895    0.060335
#
# [4 rows x 1766 columns]

# %%
xy.Index_rets.T['300'].loc[New_TSR.T.dropna()['300'][New_TSR.T.dropna()['300']>1.5].index].cumsum().plot()
# Out:
# <Axes: >

# %%
xy.Index_rets.T['300'].loc[New_TSR.T.dropna()['300'][New_TSR.T.dropna()['300']<-1.5].index].cumsum().plot()
# Out:
# <Axes: >

# %%
New_TSR_idx
# Out:
#       2016-01-06  2016-01-07  2016-01-08  2016-01-11  2016-01-12  2016-01-13  \
# 50           NaN         NaN         NaN         NaN         NaN         NaN
# 300          NaN         NaN         NaN         NaN         NaN         NaN
# 500          NaN         NaN         NaN         NaN         NaN         NaN
# 1000         NaN         NaN         NaN         NaN         NaN         NaN
#
#       2016-01-14  2016-01-15  2016-01-18  2016-01-19  ...  2023-08-14  \
# 50           NaN         NaN         NaN         NaN  ...    1.036845
# 300          NaN         NaN         NaN         NaN  ...    0.674886
# 500          NaN         NaN         NaN         NaN  ...   -0.808590
# 1000         NaN         NaN         NaN         NaN  ...   -0.903141
#
#       2023-08-15  2023-08-16  2023-08-17  2023-08-18  2023-08-21  2023-08-22  \
# 50     -0.120872   -1.270599   -1.191130   -0.897793   -0.205790    0.333828
# 300     1.442554    1.140688    1.167009    1.422207    1.376731    1.042910
# 500    -0.785352    0.259854    0.342975   -0.132225   -0.151471   -0.035225
# 1000   -0.536330   -0.129942   -0.318853   -0.392189   -1.019470   -1.341513
#
#       2023-08-23  2023-08-24  2023-08-25
# 50     -0.506408   -0.569720   -0.995978
# 300     1.347327   -0.951119   -0.649935
# 500     0.115585    1.314638    1.162880
# 1000   -0.956505    0.206201    0.483033
#
# [4 rows x 1859 columns]

# %%
New_TSR1_idx.to_csv(r'E:\PyProject\factors\NewFactor\st_New_TSR_prepost_idx1.csv')

# %%
pd.read_csv(r'E:\PyProject\factors\NewFactor\st_New_TSR_idx.csv',index_col=0).loc[[50,1000],:]
# Out:
#       2016-01-04  2016-01-05  2016-01-06  2016-01-07  2016-01-08  2016-01-11  \
# 50      0.962962    0.905180    1.155897    0.606296    0.764528    1.313461
# 1000   -1.401057   -1.421469   -1.212894   -1.482881   -1.468804   -1.049187
#
#       2016-01-12  2016-01-13  2016-01-14  2016-01-15  ...  2023-05-24  \
# 50      1.311309    1.361990    1.242439    1.209194  ...    1.061463
# 1000   -1.083691   -0.991289   -1.074822   -1.186196  ...    0.206869
#
#       2023-05-25  2023-05-26  2023-05-29  2023-05-30  2023-05-31  2023-06-01  \
# 50      1.293808    1.241196    1.215117    0.924308   -0.027575   -0.338067
# 1000   -0.198436    0.212217    0.369666    0.573506    1.407143    1.426419
#
#       2023-06-02  2023-06-05  2023-06-06
# 50     -0.766041   -0.967313   -0.910719
# 1000    1.177426    1.261440    1.298776
#
# [2 rows x 1805 columns]

# %%
# 单因子强弱
DNM_select, DNM_rets = xy.single_Factor_backtest(
    pd.read_csv(r'E:\PyProject\factors\NewFactor\st_New_TSR_idx.csv',index_col=0).loc[[50,1000],:],# ['50','1000']
    xy.Index_rets.loc[['50','1000'],'2016-01-28':],
    _side=1,
    fee=0.00,
    name='DNM'
)
# Out:
# 806.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 2
#       1 # 单因子强弱
# ----> 2 DNM_select, DNM_rets = xy.single_Factor_backtest(
#       3     pd.read_csv(r'E:\PyProject\factors\NewFactor\st_New_TSR_idx.csv',index_col=0).loc[[50,1000],:],# ['50','1000']
#       4     xy.Index_rets.loc[['50','1000'],'2016-01-28':],
#       5     _side=1,
#       6     fee=0.00,
#       7     name='DNM'
#       8 )
#
# File E:\PyProject\factors\TPS\xy.py:239, in single_Factor_backtest(Fdf, Index_rets, _side, fee, name)
#     235 (Index_rets.T.cumsum()).plot(ax=ax, label='refer Index', style='--', alpha=0.5, figsize=(15,8), grid=True)
#     237 ret = ((Index_panel_select * Index_rets).sum() - fee_series)
# --> 239 mdd = -cal_downdraw(ret.dropna())
#     240 ret_y =  (ret.dropna().sum())/len(ret.dropna())*250
#     241 sharpe = (ret.dropna().sum())/len(ret.dropna())*250 /  ((ret.dropna().std()* 250**0.5))
#
# File E:\PyProject\factors\TPS\xy.py:168, in cal_downdraw(arr)
#     166 def cal_downdraw(arr):
#     167     I = np.argmax(np.maximum.accumulate(arr.cumsum()) - arr.cumsum())
# --> 168     J = np.argmax(arr.cumsum()[:I])
#     169     return arr.cumsum()[J] - arr.cumsum()[I]
#
# File <__array_function__ internals>:200, in argmax(*args, **kwargs)
#
# File D:\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:1242, in argmax(a, axis, out, keepdims)
#    1155 """
#    1156 Returns the indices of the maximum values along an axis.
#    1157
#    (...)
#    1239 (2, 1, 4)
#    1240 """
#    1241 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1242 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File D:\anaconda3\envs\research\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\base.py:655, in IndexOpsMixin.argmax(self, axis, skipna, *args, **kwargs)
#     651         return delegate.argmax()
#     652 else:
#     653     # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     654     # "int")
# --> 655     return nanops.nanargmax(  # type: ignore[return-value]
#     656         delegate, skipna=skipna
#     657     )
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\nanops.py:1104, in nanargmax(values, axis, skipna, mask)
#    1102 values, mask, _, _, _ = _get_values(values, True, fill_value_typ="-inf", mask=mask)
#    1103 # error: Need type annotation for 'result'
# -> 1104 result = values.argmax(axis)  # type: ignore[var-annotated]
#    1105 result = _maybe_arg_null_out(result, axis, mask, skipna)
#    1106 return result
#
# ValueError: attempt to get argmax of an empty sequence

# %%
pd.read_csv(r'E:\PyProject\factors\NewFactor\st_New_TSR_idx.csv',index_col=0)
# Out:
#       2016-01-04  2016-01-05  2016-01-06  2016-01-07  2016-01-08  2016-01-11  \
# 50      0.962962    0.905180    1.155897    0.606296    0.764528    1.313461
# 300     0.302050    0.373900    0.337662    0.595247    0.281042    0.131593
# 500     0.136045    0.142389   -0.280665    0.281338    0.423233   -0.395867
# 1000   -1.401057   -1.421469   -1.212894   -1.482881   -1.468804   -1.049187
#
#       2016-01-12  2016-01-13  2016-01-14  2016-01-15  ...  2023-05-24  \
# 50      1.311309    1.361990    1.242439    1.209194  ...    1.061463
# 300     0.086411    0.031007    0.295041    0.243965  ...   -1.350465
# 500    -0.314030   -0.401708   -0.462659   -0.266963  ...    0.082132
# 1000   -1.083691   -0.991289   -1.074822   -1.186196  ...    0.206869
#
#       2023-05-25  2023-05-26  2023-05-29  2023-05-30  2023-05-31  2023-06-01  \
# 50      1.293808    1.241196    1.215117    0.924308   -0.027575   -0.338067
# 300    -1.133674   -1.149904   -1.048389   -1.338408   -0.873608   -0.903887
# 500     0.038302   -0.303509   -0.536393   -0.159406   -0.505961   -0.184464
# 1000   -0.198436    0.212217    0.369666    0.573506    1.407143    1.426419
#
#       2023-06-02  2023-06-05  2023-06-06
# 50     -0.766041   -0.967313   -0.910719
# 300    -0.892070   -0.610647   -0.645957
# 500     0.480685    0.316520    0.257900
# 1000    1.177426    1.261440    1.298776
#
# [4 rows x 1805 columns]
