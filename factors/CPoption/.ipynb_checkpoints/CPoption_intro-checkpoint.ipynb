# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat as loadmat
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.unicode_minus'] = False

# Suppress warnings`
warnings.filterwarnings("ignore")

# %%
import imp

# %%
import xy

# %% [markdown]
# # $因子描述：期权P/C持仓比（PCratio）$

# %% [markdown]
# ***收盘统计看跌、看涨期权合约持仓数量之比***

# %% [markdown]
# ## 计算

# %%
# !pip install chardet
# Out:
# Collecting chardet
#   Downloading chardet-5.1.0-py3-none-any.whl (199 kB)
#      ------------------------------------ 199.1/199.1 kB 526.1 kB/s eta 0:00:00
# Installing collected packages: chardet
# Successfully installed chardet-5.1.0

# %%
import chardet

# 读取文件的二进制数据
with open('期权数据2.csv', 'rb') as f:
    data = f.read()

# 探测文件编码
result = chardet.detect(data)
encoding = result['encoding']

# %% [markdown]
# ### 小市值

# %%
size = pd.read_csv(r'E:/PyProject/factors/DailyFactor/size.csv',index_col=0)
size.index = size.index.map(lambda x: str(x)[:6] +'.SZ' if x[-1]=='E' else str(x)[:6] +'.SH')

# %%
_f = (size.shift(1,axis=1)*xy.filter1)
frank = _f.rank()
defrank = _f.rank(ascending=False)

# %%
xy.cal_rate_group(((size.shift(1,axis=1)*xy.filter1).loc[:,'2016-01-04':]),xy.rets.loc[:,'2016-01-04':],group_num=10,masks=1).cumsum().plot()
# Out:
# -0.11741163744001733
# 1 358.41495844875345
# 2 358.91911357340723
# 3 358.8160664819945
# 4 358.9218836565097
# 5 359.01772853185594
# 6 358.6936288088643
# 7 358.8265927977839
# 8 358.9113573407202
# 9 358.82382271468146
# 10 359.30526315789473
# <Axes: >

# %%
((_f[defrank<200]/_f[defrank<200]) * xy.rets).mean().dropna()
# Out:
# 2016-01-05   -0.001611
# 2016-01-06    0.022613
# 2016-01-07   -0.076742
# 2016-01-08    0.023312
# 2016-01-11   -0.051589
#                 ...
# 2023-04-27    0.006550
# 2023-04-28    0.012037
# 2023-05-04    0.002890
# 2023-05-05   -0.004128
# 2023-05-08    0.016111
# Length: 1783, dtype: float64

# %%
xx = (((_f[frank<200]/_f[frank<200]) * xy.rets).mean()).dropna().rolling(1).sum()
xx.plot(figsize=(15,8),secondary_y=True,grid=True)
xy.Index_rets.loc['1000',xx.index].cumsum().plot(figsize=(15,8),grid=True)
# Out:
# <Axes: >

# %%
_f['2022-12-30'].dropna().sort_values()
# Out:
# 688701.SH   -3.406747
# 688004.SH   -3.349005
# 300478.SZ   -3.337546
# 688215.SH   -3.318326
# 603729.SH   -3.313826
#                ...
# 300274.SZ    0.991380
# 300124.SZ    0.991380
# 300122.SZ    0.991380
# 300015.SZ    0.991380
# 000001.SZ    0.991380
# Name: 2022-12-30, Length: 4618, dtype: float64

# %%
xy.rets.loc[_f['2022-12-30'].dropna().sort_values()[:200].index,'2022-12-30'].mean()
# Out:
# 0.00941391116013969

# %%
xx['2022-12-30']
# Out:
# 0.009431036311667999

# %%
xy.Index_rets.loc['50',xx.index].corr(xx.shift(1))
# Out:
# -0.07166554844045972

# %%
_f['2023-01-03'].dropna().sort_values()
# Out:
# 688701.SH   -3.419101
# 688004.SH   -3.355793
# 300478.SZ   -3.347469
# 688081.SH   -3.321900
# 603709.SH   -3.315896
#                ...
# 600011.SH    0.993476
# 600009.SH    0.993476
# 600000.SH    0.993476
# 600036.SH    0.993476
# 000001.SZ    0.993476
# Name: 2023-01-03, Length: 4618, dtype: float64

# %%
(size*xy.filter1)['2022-12-30'].dropna().sort_values()
# Out:
# 688701.SH   -3.419101
# 688004.SH   -3.355793
# 300478.SZ   -3.347469
# 688081.SH   -3.321900
# 603709.SH   -3.315896
#                ...
# 600011.SH    0.993476
# 600009.SH    0.993476
# 600000.SH    0.993476
# 600036.SH    0.993476
# 000001.SZ    0.993476
# Name: 2022-12-30, Length: 4618, dtype: float64

# %%
((((_f[frank<200]/_f[frank<200]) * xy.rets).mean().loc['2021-01-04':]-0.0008).cumsum()).plot()
xy.Index_rets.loc['1000','2021-01-04':].cumsum().plot()
# Out:
# <Axes: >

# %%
((((_f[frank<200]/_f[frank<200]) * xy.rets).mean().loc['2021-01-04':]) - xy.Index_rets.loc['1000','2021-01-04':] - 0.0008).dropna().cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### END

# %%
# 使用探测到的编码读取文件
df50 = pd.read_csv('OP510050.csv',index_col=0,header=1)
df500 = pd.read_csv('OP510500.csv',index_col=0,header=1,encoding=encoding)
df300 = pd.read_csv('OP510300.csv',index_col=0,header=1,encoding=encoding)

# %%
c_chg50 = df50['C持仓量'].pct_change()

# %%
p_chg50 = df50['P持仓量'].pct_change()

# %%
option50etf = df50['P持仓量'].rolling(1).mean() / df50['C持仓量'].rolling(1).mean()
# option300etf = df300['P/C持仓']
# option500etf = df500['P/C持仓']
# option1000etf = df[df.SECURITY_CODE==852].set_index('TRADE_DATE')

# %%
option50etf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 全局百分位

# %%
same_dt = xy.Index_rets.loc['50',:].index & ((option50etf.shift(1).rank()/len(option50etf.shift(1)))).index

# %%
sig = (option50etf.shift(0).rank()/option50etf.shift(0).shape[0])

# %%
((sig/0.5)**3).plot()
# Out:
# <Axes: >

# %%
short = (xy.Index_rets.loc['50',same_dt][(sig>0.8).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
short_df = pd.concat([
    short,
    pd.Series(-1,short.index).rename('方向'),
    pd.Series(sig,short.index).rename('P/C全局百分位')
],axis=1)

long = (xy.Index_rets.loc['50',same_dt][(sig<0.2).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
long_df = pd.concat([
    long,
    pd.Series(1,long.index).rename('方向'),
    pd.Series(sig,long.index).rename('P/C全局百分位')
],axis=1)

empt = (xy.Index_rets.loc['50',same_dt][((sig>=0.2) & (sig<=0.8)).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
empt_df = pd.concat([
    empt,
    pd.Series(np.nan,empt.index).rename('方向'),
    pd.Series(sig,empt.index).rename('P/C全局百分位')
],axis=1)

# %%
CPratio_res50_03 = pd.concat([
    long_df,
    short_df,
    empt_df
]).sort_index()

# %%
CPratio_res50_03['方向'] = CPratio_res50_03['方向'].ffill()

CPratio_res50_03['未扣费累计收益'] = (CPratio_res50_03.收益率 * CPratio_res50_03.方向.shift(1)).cumsum()
CPratio_res50_03['扣费累计收益'] = (CPratio_res50_03.收益率 * CPratio_res50_03.方向.shift(1) - 0.001).cumsum()
CPratio_res50_03['百分位阈值'] = '0.3/0.7'

# %%
CPratio_res50_03['P/C'] = option50etf.shift(1)

CPratio_res50_03['未扣费累计收益'].plot()
# Out:
# <Axes: >

# %%
CPratio_res50_03.dropna()
# Out:
#                  收益率   方向  P/C全局百分位   未扣费累计收益    扣费累计收益    百分位阈值   P/C
# 2016-01-11 -0.044773  1.0  0.057070 -0.044773 -0.045773  0.3/0.7  60.0
# 2016-01-12  0.005251  1.0  0.049908 -0.039521 -0.041521  0.3/0.7  55.0
# 2016-01-13 -0.012134  1.0  0.044362 -0.051655 -0.054655  0.3/0.7  54.0
# 2016-01-14  0.012619  1.0  0.027726 -0.039036 -0.043036  0.3/0.7  53.0
# 2016-01-15 -0.028680  1.0  0.023799 -0.067716 -0.072716  0.3/0.7  49.0
# ...              ...  ...       ...       ...       ...      ...   ...
# 2023-05-26 -0.001907  1.0  0.176756 -0.138404 -1.931404  0.3/0.7  66.0
# 2023-05-29 -0.004426  1.0  0.144409 -0.142830 -1.936830  0.3/0.7  66.0
# 2023-05-30 -0.005157  1.0  0.116913 -0.147987 -1.942987  0.3/0.7  64.0
# 2023-05-31 -0.016486  1.0  0.080176 -0.164473 -1.960473  0.3/0.7  62.0
# 2023-06-01  0.002803  1.0  0.086876 -0.161670 -1.958670  0.3/0.7  58.0
#
# [1797 rows x 7 columns]

# %%
CPratio_res50_03['收益率'].loc['2016-08-14':].cumsum().plot(figsize=(20,8))
CPratio_res50_03['未扣费累计收益'].loc['2016-08-14':].plot(figsize=(20,8))
CPratio_res50_03['P/C全局百分位'].loc['2016-08-14':].plot(secondary_y=True,figsize=(20,8),alpha=0.3)
CPratio_res50_03['P/C全局百分位'].map(lambda x:-5 if x>0.8 else(5 if x<0.2 else np.nan)).ffill().loc['2016-08-14':].plot(secondary_y=True,figsize=(20,8),color='black')
# Out:
# <Axes: >

# %%
# pd.concat([
#     CPratio_res50_01,
#     CPratio_res50_02,
#     CPratio_res50_03
# ]).to_excel('CPratio_res50_quantile.xlsx')

# %% [markdown]
# ### 滚动百分位

# %%
imp.reload(xy)
# Out:
# <module 'xy' from 'E:\\PyProject\\factors\\CPoption\\xy.py'>

# %%
TR = pd.concat([
    (xy.index_high.T['50'] - xy.index_low.T['50']),
    (xy.index_high.T['50'] - xy.cl.T['50'].shift(1)),
    (xy.cl.T['50'].shift(1) - xy.index_low.T['50'])
],axis=1).dropna().max(axis=1)

ATR15 = TR.rolling(20).mean().dropna()

# %%
ATR15.plot()
xy.Index_rets.loc['50',ATR15.index].cumsum().plot(secondary_y=True)
ATR15.shift(1).corr(xy.Index_rets.loc['50',ATR15.index])
# Out:
# -0.02597350257120088

# %%
same_dt = xy.Index_rets.loc['50',:].index & ((ATR15.shift(0).rank()/len(ATR15.shift(0)))).index

# %%
same_dt = xy.Index_rets.loc['50',:].index & ((option50etf.shift(0).rank()/len(option50etf.shift(0)))).index

# %%
# sig.dropna().loc[same_dt].plot(figsize=(20,8))
sig = (option50etf).loc[same_dt].rolling(15).apply(lambda x:((x.rank()[-1]/len(x))))
# sig.rolling(240).apply(lambda x:((x.rank()[-1]/len(x)))).plot(figsize=(20,8),alpha=0.3)
# sig.plot(figsize=(20,8))
sig.loc[same_dt].loc['2016-02-09':'2023-08-16'].shift(1).plot(figsize=(20,8),grid=True,alpha=0.5)
# sig.loc[same_dt].loc['2019-02-09':'2023-08-16'].map(lambda x: 1 if x>0.6 else (np.nan if x>0.4 else -1)).ffill().shift(1).plot(figsize=(20,8),grid=True,color='black')
# sig = ((sig/sig.rolling(20).mean())**30).map(lambda x:1 if x>1 else x)
# sig.plot(figsize=(20,8))
# ((sig/sig.rolling(20).mean())**30).map(lambda x:1 if x>1 else x).plot(figsize=(20,8))
# sig.plot(figsize=(20,8))
# (option50etf**10).map(lambda x:-5 if x>3 else(5 if x<0.2 else np.nan)).ffill().dropna().loc[same_dt].plot(figsize=(20,8))
(sig.loc[same_dt].loc['2016-02-09':'2023-08-16'].map(lambda x: 1 if x>0.8 else (np.nan if x>0.2 else -1)).ffill().shift(1) * xy.Index_rets.loc['50',same_dt].loc['2016-02-09':'2023-08-16']).cumsum().plot(figsize=(20,8),secondary_y=True)
xy.Index_rets.loc['50',same_dt].loc['2016-02-09':'2023-08-16'].cumsum().plot(figsize=(20,8),secondary_y=True)
# (p_chg50.dropna().loc[same_dt]).rolling(5).mean().loc['2020-08-14':].plot(figsize=(20,8))
# (c_chg50.dropna().loc[same_dt]).rolling(5).mean().loc['2020-08-14':].plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
# P/C上升，大多数情况是P减得比C慢

# %%
short = (xy.Index_rets.loc['50',same_dt][(sig.rolling(1).mean()>0.80).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
short_df = pd.concat([
    short,
    pd.Series(1,short.index).rename('方向'),
    pd.Series((sig),short.index).rename('P/C240日百分位')
],axis=1)

long = (xy.Index_rets.loc['50',same_dt][((sig.rolling(1).mean())<0.2).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
long_df = pd.concat([
    long,
    pd.Series(-1,long.index).rename('方向'),
    pd.Series((sig),long.index).rename('P/C240日百分位')
],axis=1)

empt = (xy.Index_rets.loc['50',same_dt][(((sig.rolling(1).mean())>=0.2) & (sig.rolling(1).mean()<=0.80)).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
empt_df = pd.concat([
    empt,
    pd.Series(np.nan,empt.index).rename('方向'),
    pd.Series((sig),empt.index).rename('P/C240日百分位')
],axis=1)

# %%
CPratio_res50_02 = pd.concat([
    long_df,
    short_df,
    empt_df
]).sort_index()

# %%
shrd_loss = 0.02
shrd_profit = 0.02

# %%
def cal_downdraw(arr):
    if len(arr) == 0:
        return 0
        
    I = np.argmax(np.maximum.accumulate(arr.cumsum()) - arr.cumsum()) 
    # print(I)
    if (I == 0) & any(arr<0):
        return  abs(arr[0])
    elif (I == len(arr)) & any(arr<0):
        return  abs(arr.sum())
    elif all(arr>=0):
        return -abs(arr.sum())
    
    J = np.argmax(arr.cumsum()[:I])
    # print(I,J)
    # print(arr.cumsum()[J], arr.cumsum()[I], arr.cumsum()[J] - arr.cumsum()[I])
    return arr.cumsum()[J] - arr.cumsum()[I]

# %%
def cal_pnl_win_cutloss(x):
    # display(x)
    if len(x) == 1:
        return x.index[0], max(-shrd_loss, x.values[0])
    elif all(np.isclose(x,0.0)):
        return x.index[0], 0
    else:
        for i in range(x.shape[0]):
            # print(x[:i+1])
            
            mdd = -cal_downdraw(x[:i+1])
            pre_mdd = -cal_downdraw(x[:i])
            shrd_pre_mdd = abs(shrd_loss + pre_mdd)
            # print(x.index[i],pre_mdd,mdd,x[:i].sum(),x[i])
            if mdd < -shrd_loss:
                return x.index[i], max(x[:i+1].sum(),-shrd_loss)#x[:i].sum() - shrd_pre_mdd

    return x.index[i], x[:i+1].sum()

def cal_pnl_win_cutprofit(x):
    if len(x) == 1:
        return x.index[0], min(shrd_profit, x.values[0])
    elif all(np.isclose(x,0.0)):
        return x.index[0], 0
    else:
        for i in range(x.shape[0]):
            mp = x[:i+1].sum()
            if mp >= shrd_profit:
                return x.index[i], shrd_profit

    return x.index[i], x[:i+1].sum()

def cal_pnl_win_cutboth(x):
    if len(x) == 1:
        return x.index[0], x.values[0]
    elif all(np.isclose(x,0.0)):
        return x.index[0], 0
    else:
        for i in range(x.shape[0]):
            mdd = -cal_downdraw(x[:i+1])
            pre_mdd = -cal_downdraw(x[:i])
            shrd_pre_mdd = abs(shrd_loss + pre_mdd)
            mp = x[:i+1].sum()
            if (mp >= shrd_profit) & (mdd > -shrd_loss):
                return x.index[i], shrd_profit
            elif (mdd < -shrd_loss) & (mp <= shrd_profit):
                return x.index[i], max(x[:i+1].sum(),-shrd_loss)#-shrd_loss#x[:i].sum() - shrd_pre_mdd
            else:
                pass

    return x.index[i], x[:i+1].sum()

# %%
pre_side = np.nan
long_dates = []
short_dates = []
for _d, _row in CPratio_res50_02.iterrows():
    # print(pre_side,_row.方向,_row['P/C240日百分位'])
    if np.isnan(_row.方向) & (pre_side>0) & (_row['P/C240日百分位']>=0.6):
        # print(_d)
        long_dates.append(_d)
        pre_side = _row.方向
        
    elif np.isnan(_row.方向) & (pre_side<0) & (_row['P/C240日百分位']<=0.4):
        short_dates.append(_d)
        pre_side = _row.方向
    
    else:
        pre_side = _row.方向
        continue
    
# CPratio_res50_02

# %%
CPratio_res50_02['收益率'][:].corr(CPratio_res50_02['方向'][:].shift(1))
# Out:
# 0.07250302923011255

# %%
CPratio_res50_02.loc[long_dates,'方向'] = 1
CPratio_res50_02.loc[short_dates,'方向'] = -1

# %%
CPratio_res50_02['收益率'][:].corr(CPratio_res50_02['方向'][:].shift(1))
# Out:
# 0.08467867997963929

# %%
CPratio_res50_02['方向'] = CPratio_res50_02['方向'].shift(1)
CPratio_res50_02['方向1'] = CPratio_res50_02['方向'].fillna(0)

# %%
CPratio_res50_02['收益率'][:].corr(CPratio_res50_02['方向1'][:])
# Out:
# 0.0683474043418046

# %%
CPratio_res50_02['ret'] = CPratio_res50_02['收益率'] * CPratio_res50_02['方向1']

# %%
CPratio_res50_02['flag'] = (CPratio_res50_02['方向1']!=CPratio_res50_02['方向1'].shift(1)).cumsum()

# %%
ddct = dict(zip(CPratio_res50_02['flag'][(CPratio_res50_02['方向1']!=CPratio_res50_02['方向1'].shift(1))].values,
                CPratio_res50_02['flag'][(CPratio_res50_02['方向1']!=CPratio_res50_02['方向1'].shift(1))].index))

# %%
CPratio_res50_02['flag'] = CPratio_res50_02['flag'].map(lambda x:ddct[x])

# %%
CPratio_res50_02 = CPratio_res50_02[~pd.isna(CPratio_res50_02['ret'])]

# %%
CPratio_res50_02
# Out:
#                  收益率   方向  P/C240日百分位  方向1       ret        flag
# 2016-01-04 -0.062103  NaN    0.533333  0.0 -0.000000  2016-01-04
# 2016-01-05  0.007775  NaN    0.333333  0.0  0.000000  2016-01-04
# 2016-01-06  0.012907  NaN    0.266667  0.0  0.000000  2016-01-04
# 2016-01-07 -0.059137  NaN    0.200000  0.0 -0.000000  2016-01-04
# 2016-01-08  0.017896  NaN    0.066667  0.0  0.000000  2016-01-04
# ...              ...  ...         ...  ...       ...         ...
# 2023-05-26 -0.001907 -1.0    0.066667 -1.0  0.001907  2023-05-22
# 2023-05-29 -0.004426 -1.0    0.066667 -1.0  0.004426  2023-05-22
# 2023-05-30 -0.005157 -1.0    0.066667 -1.0  0.005157  2023-05-22
# 2023-05-31 -0.016486 -1.0    0.066667 -1.0  0.016486  2023-05-22
# 2023-06-01  0.002803 -1.0    0.133333 -1.0 -0.002803  2023-05-22
#
# [1802 rows x 6 columns]

# %%
ss = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutloss).map(lambda x:x[1])
pp = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutprofit).map(lambda x:x[1])
bb = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutboth).map(lambda x:x[1])

ss_date = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutloss).map(lambda x:x[0])
pp_date = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutprofit).map(lambda x:x[0])
bb_date = CPratio_res50_02.groupby('flag')['ret'].apply(cal_pnl_win_cutboth).map(lambda x:x[0])

# %%
CPratio_res50_02['win_cutloss_pnl'] = pd.Series(pd.Series(ss.values,index=ss_date.values),CPratio_res50_02.index)
CPratio_res50_02['win_cutprofit_pnl'] = pd.Series(pd.Series(pp.values,index=pp_date.values),CPratio_res50_02.index)
CPratio_res50_02['win_cutboth_pnl'] = pd.Series(pd.Series(bb.values,index=bb_date.values),CPratio_res50_02.index)

# CPratio_res50_02['win_cutloss_pnl_date'] = pd.Series(ss_date,index=CPratio_res50_02.index)
# CPratio_res50_02['win_cutprofit_pnl_date'] = pd.Series(pp_date,index=CPratio_res50_02.index)
# CPratio_res50_02['win_cutboth_pnl_date'] = pd.Series(bb_date,index=CPratio_res50_02.index)

# %%
CPratio_res50_02['未扣费累计收益'] = CPratio_res50_02.ret.cumsum()
# CPratio_res50_02['扣费累计收益'] = (CPratio_res50_02.收益率 * CPratio_res50_02.方向.ffill() - 0.001).cumsum()
CPratio_res50_02['百分位阈值'] = '0.2/0.8'

CPratio_res50_02['P/C'] = option50etf
CPratio_res50_02['未扣费累计收益'].loc['2016-01-14':].rename('fall_cut_0.5').plot(figsize=(20,8),legend=True)
CPratio_res50_02['P/C'].loc['2016-01-14':].plot(figsize=(20,8),grid=True,alpha=0.3)

# CPratio_res50_02['P/C240日百分位'].loc['2016-08-14':].map(lambda x: 1 if x>0.6 else (np.nan if x>0.4 else -1)).ffill().shift(1).plot(figsize=(20,8),grid=True,color='black')

pd.Series(ss,index=CPratio_res50_02.index).fillna(0).cumsum().loc['2016-01-14':].rename('cut_loss').plot(figsize=(20,8),grid=True,legend=True)
# pd.Series(pp,index=CPratio_res50_02.index).fillna(0).cumsum().loc['2016-01-14':].rename('cut_profit').plot(figsize=(20,8),legend=True)
# pd.Series(bb,index=CPratio_res50_02.index).fillna(0).cumsum().loc['2016-01-14':].rename('cut_both').plot(figsize=(20,8),legend=True)
CPratio_res50_02['收益率'].cumsum().rename('指数').loc['2016-01-14':].plot(figsize=(20,8),alpha=0.3,legend=True)
(sig.loc['2016-01-14':].map(lambda x: 1 if x>0.7 else (np.nan if x>0.3 else -1)).ffill().shift(1) * xy.Index_rets.loc['50',:].loc['2016-01-14':]).cumsum().rename('no_cut').plot(figsize=(20,8),style='-',legend=True,grid=True)
# Out:
# <Axes: >

# %%
sig.loc[same_dt].loc['2016-01-14':].map(lambda x: 1 if x>0.8 else (np.nan if x>0.2 else -1)).ffill().shift(1).diff().abs().sum()
# Out:
# 252.0

# %%
CPratio_res50_02[:].方向1.diff().abs().sum()
# Out:
# 407.0

# %%
CPratio_res50_02
# Out:
#                  收益率   方向  P/C240日百分位  方向1       ret        flag  \
# 2016-01-04 -0.062103  NaN    0.533333  0.0 -0.000000  2016-01-04
# 2016-01-05  0.007775  NaN    0.333333  0.0  0.000000  2016-01-04
# 2016-01-06  0.012907  NaN    0.266667  0.0  0.000000  2016-01-04
# 2016-01-07 -0.059137  NaN    0.200000  0.0 -0.000000  2016-01-04
# 2016-01-08  0.017896  NaN    0.066667  0.0  0.000000  2016-01-04
# ...              ...  ...         ...  ...       ...         ...
# 2023-05-26 -0.001907 -1.0    0.066667 -1.0  0.001907  2023-05-22
# 2023-05-29 -0.004426 -1.0    0.066667 -1.0  0.004426  2023-05-22
# 2023-05-30 -0.005157 -1.0    0.066667 -1.0  0.005157  2023-05-22
# 2023-05-31 -0.016486 -1.0    0.066667 -1.0  0.016486  2023-05-22
# 2023-06-01  0.002803 -1.0    0.133333 -1.0 -0.002803  2023-05-22
#
#             win_cutloss_pnl  win_cutprofit_pnl  win_cutboth_pnl   未扣费累计收益  \
# 2016-01-04         0.000000                0.0              0.0 -0.000000
# 2016-01-05              NaN                NaN              NaN  0.000000
# 2016-01-06              NaN                NaN              NaN  0.000000
# 2016-01-07              NaN                NaN              NaN  0.000000
# 2016-01-08              NaN                NaN              NaN  0.000000
# ...                     ...                ...              ...       ...
# 2023-05-26              NaN                NaN              NaN  1.160980
# 2023-05-29              NaN                NaN              NaN  1.165406
# 2023-05-30              NaN                NaN              NaN  1.170563
# 2023-05-31              NaN                NaN              NaN  1.187049
# 2023-06-01         0.051378                NaN              NaN  1.184246
#
#               百分位阈值       P/C
# 2016-01-04  0.2/0.8  0.807917
# 2016-01-05  0.2/0.8  0.707534
# 2016-01-06  0.2/0.8  0.702487
# 2016-01-07  0.2/0.8  0.695279
# 2016-01-08  0.2/0.8  0.595804
# ...             ...       ...
# 2023-05-26  0.2/0.8  0.656661
# 2023-05-29  0.2/0.8  0.635870
# 2023-05-30  0.2/0.8  0.616981
# 2023-05-31  0.2/0.8  0.578451
# 2023-06-01  0.2/0.8  0.589063
#
# [1802 rows x 12 columns]

# %%
CPratio_res50_02.win_cutloss_pnl.sort_values().dropna()
# Out:
# 2021-08-25   -0.028100
# 2019-12-30   -0.025526
# 2018-01-02   -0.024206
# 2022-03-04   -0.020376
# 2021-01-26   -0.020000
#                 ...
# 2021-01-14    0.065503
# 2020-03-20    0.076542
# 2020-02-04    0.085020
# 2018-01-24    0.085937
# 2020-07-09    0.137080
# Name: win_cutloss_pnl, Length: 392, dtype: float64

# %%
CPratio_res50_02.loc[:'2017-06-22'][-15:]['P/C'].rank()/15
# Out:
# 2017-06-02    0.600000
# 2017-06-05    0.333333
# 2017-06-06    0.266667
# 2017-06-07    0.533333
# 2017-06-08    0.666667
# 2017-06-09    0.866667
# 2017-06-12    1.000000
# 2017-06-13    0.933333
# 2017-06-14    0.733333
# 2017-06-15    0.400000
# 2017-06-16    0.066667
# 2017-06-19    0.200000
# 2017-06-20    0.133333
# 2017-06-21    0.466667
# 2017-06-22    0.800000
# Name: P/C, dtype: float64

# %%
CPratio_res50_02.loc['2017-06-07':'2017-06-23'].head(30)
# Out:
#                  收益率   方向  P/C240日百分位  方向1       ret        flag  \
# 2017-06-07  0.007310  NaN    0.733333  0.0  0.000000  2017-06-07
# 2017-06-08  0.009259  NaN    0.933333  0.0  0.000000  2017-06-07
# 2017-06-09  0.004882  1.0    1.000000  1.0  0.004882  2017-06-09
# 2017-06-12  0.000752  1.0    1.000000  1.0  0.000752  2017-06-09
# 2017-06-13 -0.002390  1.0    0.933333  1.0 -0.002390  2017-06-09
# 2017-06-14 -0.015039  1.0    0.800000  1.0 -0.015039  2017-06-09
# 2017-06-15 -0.006194  1.0    0.333333  1.0 -0.006194  2017-06-09
# 2017-06-16 -0.003730  NaN    0.066667  0.0 -0.000000  2017-06-16
# 2017-06-19  0.012772 -1.0    0.133333 -1.0 -0.012772  2017-06-19
# 2017-06-20 -0.003901 -1.0    0.133333 -1.0  0.003901  2017-06-19
# 2017-06-21  0.009226  NaN    0.466667  0.0  0.000000  2017-06-21
# 2017-06-22  0.007776  NaN    0.800000  0.0  0.000000  2017-06-21
# 2017-06-23  0.004937  NaN    1.000000  0.0  0.000000  2017-06-21
#
#             win_cutloss_pnl  win_cutprofit_pnl  win_cutboth_pnl   未扣费累计收益  \
# 2017-06-07         0.000000           0.000000         0.000000  0.230060
# 2017-06-08              NaN                NaN              NaN  0.230060
# 2017-06-09              NaN                NaN              NaN  0.234942
# 2017-06-12              NaN                NaN              NaN  0.235695
# 2017-06-13              NaN                NaN              NaN  0.233305
# 2017-06-14              NaN                NaN              NaN  0.218266
# 2017-06-15        -0.017988          -0.017988        -0.017988  0.212072
# 2017-06-16        -0.000000          -0.000000        -0.000000  0.212072
# 2017-06-19              NaN                NaN              NaN  0.199300
# 2017-06-20        -0.008871          -0.008871        -0.008871  0.203202
# 2017-06-21         0.000000           0.000000         0.000000  0.203202
# 2017-06-22              NaN                NaN              NaN  0.203202
# 2017-06-23              NaN                NaN              NaN  0.203202
#
#               百分位阈值       P/C
# 2017-06-07  0.2/0.8  1.072638
# 2017-06-08  0.2/0.8  1.117897
# 2017-06-09  0.2/0.8  1.215102
# 2017-06-12  0.2/0.8  1.246247
# 2017-06-13  0.2/0.8  1.237536
# 2017-06-14  0.2/0.8  1.148528
# 2017-06-15  0.2/0.8  1.059229
# 2017-06-16  0.2/0.8  1.026953
# 2017-06-19  0.2/0.8  1.039693
# 2017-06-20  0.2/0.8  1.027981
# 2017-06-21  0.2/0.8  1.068287
# 2017-06-22  0.2/0.8  1.209641
# 2017-06-23  0.2/0.8  1.247026

# %%
CPratio_res50_02.loc[CPratio_res50_02.win_cutboth_pnl.dropna().index,:]
# Out:
#                  收益率   方向  P/C240日百分位  方向1       ret        flag  \
# 2016-01-22  0.010282  NaN    0.066667  0.0  0.000000  2016-01-22
# 2016-01-26 -0.055112 -1.0    0.066667 -1.0  0.055112  2016-01-25
# 2016-01-28 -0.020857  NaN    0.333333  0.0 -0.000000  2016-01-28
# 2016-02-15 -0.009650  1.0    0.266667  1.0 -0.009650  2016-02-05
# 2016-02-16  0.027012  NaN    0.933333  0.0  0.000000  2016-02-16
# ...              ...  ...         ...  ...       ...         ...
# 2023-04-27  0.012449 -1.0    0.333333 -1.0 -0.012449  2023-04-24
# 2023-04-28  0.010257  NaN    0.533333  0.0  0.000000  2023-04-28
# 2023-05-10 -0.011106  1.0    0.400000  1.0 -0.011106  2023-05-09
# 2023-05-11 -0.002934  NaN    0.333333  0.0 -0.000000  2023-05-11
# 2023-05-29 -0.004426 -1.0    0.066667 -1.0  0.004426  2023-05-22
#
#             win_cutloss_pnl  win_cutprofit_pnl  win_cutboth_pnl   未扣费累计收益  \
# 2016-01-22         0.000000           0.000000         0.000000  0.000000
# 2016-01-26              NaN           0.030000         0.030000  0.053423
# 2016-01-28         0.000000           0.000000         0.000000  0.052475
# 2016-02-15        -0.013184          -0.013184        -0.013184  0.039291
# 2016-02-16         0.000000           0.000000         0.000000  0.039291
# ...                     ...                ...              ...       ...
# 2023-04-27         0.001204           0.001204         0.001204  0.771837
# 2023-04-28         0.000000           0.000000         0.000000  0.771837
# 2023-05-10        -0.017130          -0.017130        -0.017130  0.754707
# 2023-05-11         0.000000           0.000000         0.000000  0.754707
# 2023-05-29              NaN           0.030000         0.030000  0.787246
#
#               百分位阈值       P/C
# 2016-01-22  0.2/0.8  0.463054
# 2016-01-26  0.2/0.8  0.384937
# 2016-01-28  0.2/0.8  0.476575
# 2016-02-15  0.2/0.8  0.466391
# 2016-02-16  0.2/0.8  0.493598
# ...             ...       ...
# 2023-04-27  0.2/0.8  0.878603
# 2023-04-28  0.2/0.8  0.938675
# 2023-05-10  0.2/0.8  0.902226
# 2023-05-11  0.2/0.8  0.878240
# 2023-05-29  0.2/0.8  0.635870
#
# [396 rows x 12 columns]

# %%
CPratio_res50_02
# Out:
#                  收益率   方向  P/C240日百分位  方向1       ret        flag  \
# 2016-01-22  0.010282  NaN    0.066667  0.0  0.000000  2016-01-22
# 2016-01-25  0.001688 -1.0    0.066667 -1.0 -0.001688  2016-01-25
# 2016-01-26 -0.055112 -1.0    0.066667 -1.0  0.055112  2016-01-25
# 2016-01-27  0.000948 -1.0    0.666667 -1.0 -0.000948  2016-01-25
# 2016-01-28 -0.020857  NaN    0.333333  0.0 -0.000000  2016-01-28
# ...              ...  ...         ...  ...       ...         ...
# 2023-05-26 -0.001907 -1.0    0.066667 -1.0  0.001907  2023-05-22
# 2023-05-29 -0.004426 -1.0    0.066667 -1.0  0.004426  2023-05-22
# 2023-05-30 -0.005157 -1.0    0.066667 -1.0  0.005157  2023-05-22
# 2023-05-31 -0.016486 -1.0    0.066667 -1.0  0.016486  2023-05-22
# 2023-06-01  0.002803 -1.0    0.133333 -1.0 -0.002803  2023-05-22
#
#             win_cutloss_pnl  win_cutprofit_pnl  win_cutboth_pnl   未扣费累计收益  \
# 2016-01-22         0.000000               0.00             0.00  0.000000
# 2016-01-25              NaN                NaN              NaN -0.001688
# 2016-01-26              NaN               0.03             0.03  0.053423
# 2016-01-27         0.052475                NaN              NaN  0.052475
# 2016-01-28         0.000000               0.00             0.00  0.052475
# ...                     ...                ...              ...       ...
# 2023-05-26              NaN                NaN              NaN  0.782820
# 2023-05-29              NaN               0.03             0.03  0.787246
# 2023-05-30              NaN                NaN              NaN  0.792403
# 2023-05-31              NaN                NaN              NaN  0.808889
# 2023-06-01         0.051378                NaN              NaN  0.806086
#
#               百分位阈值       P/C
# 2016-01-22  0.2/0.8  0.463054
# 2016-01-25  0.2/0.8  0.447971
# 2016-01-26  0.2/0.8  0.384937
# 2016-01-27  0.2/0.8  0.505845
# 2016-01-28  0.2/0.8  0.476575
# ...             ...       ...
# 2023-05-26  0.2/0.8  0.656661
# 2023-05-29  0.2/0.8  0.635870
# 2023-05-30  0.2/0.8  0.616981
# 2023-05-31  0.2/0.8  0.578451
# 2023-06-01  0.2/0.8  0.589063
#
# [1788 rows x 12 columns]

# %%
CPratio_res50_02['收益率'].loc['2016-08-14':].cumsum().plot(figsize=(20,8))
CPratio_res50_02['未扣费累计收益'].loc['2016-08-14':].plot(figsize=(20,8))
CPratio_res50_02['P/C240日百分位'].loc['2016-08-14':].plot(figsize=(20,8),alpha=0.3)
# CPratio_res50_02['P/C240日百分位'].map(lambda x:-5 if x>0.9 else(5 if x<0.1 else np.nan)).ffill().loc['2016-08-14':].plot(secondary_y=True,figsize=(20,8),color='black')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '未扣费累计收益'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2925], line 2
#       1 CPratio_res50_02['收益率'].loc['2016-08-14':].cumsum().plot(figsize=(20,8))
# ----> 2 CPratio_res50_02['未扣费累计收益'].loc['2016-08-14':].plot(figsize=(20,8))
#       3 CPratio_res50_02['P/C240日百分位'].loc['2016-08-14':].plot(figsize=(20,8),alpha=0.3)
#       4 # CPratio_res50_02['P/C240日百分位'].map(lambda x:-5 if x>0.9 else(5 if x<0.1 else np.nan)).ffill().loc['2016-08-14':].plot(secondary_y=True,figsize=(20,8),color='black')
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\anaconda3\envs\research\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '未扣费累计收益'

# %%
# pd.concat([
#     CPratio_res50_01,
#     CPratio_res50_02,
#     CPratio_res50_03,
#     CPratio_res50_04
# ]).to_excel('CPratio_res50_240quantile.xlsx')

# %% [markdown]
# ### 滚动Z

# %%
same_dt = xy.Index_rets.loc['50',:].index & ((option50etf.shift(1).rank()/len(option50etf.shift(1)))).index

# %%
short = (xy.Index_rets.loc['50',same_dt][((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std()))>2.5).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
short_df = pd.concat([
    short,
    pd.Series(-1,short.index).rename('方向'),
    pd.Series((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std())),short.index).rename('P/C240日Z值')
],axis=1)

long = (xy.Index_rets.loc['50',same_dt][((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std()))<-2.5).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
long_df = pd.concat([
    long,
    pd.Series(1,long.index).rename('方向'),
    pd.Series((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std())),long.index).rename('P/C240日Z值')
],axis=1)

empt = (xy.Index_rets.loc['50',same_dt][(((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std()))>=-2.5) & ((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std()))<=2.5)).loc[same_dt].values]).loc['2016-01-04':].rename('收益率')
empt_df = pd.concat([
    empt,
    pd.Series(np.nan,empt.index).rename('方向'),
    pd.Series((option50etf.shift(0).rolling(240).apply(lambda x:(x[-1]-x.mean())/x.std())),empt.index).rename('P/C240日Z值')
],axis=1)

# %%
CPratio_res50_03 = pd.concat([
    long_df,
    short_df,
    empt_df
]).sort_index()

# %%
CPratio_res50_03['方向'] = CPratio_res50_03['方向'].ffill()

# %%
CPratio_res50_03['未扣费累计收益'] = (CPratio_res50_03.收益率 * CPratio_res50_03.方向.shift(1)).cumsum()
CPratio_res50_03['扣费累计收益'] = (CPratio_res50_03.收益率 * CPratio_res50_03.方向.shift(1) - 0.001).cumsum()
CPratio_res50_03['百分位阈值'] = '2.5倍'

CPratio_res50_03['P/C'] = option50etf.shift(1)

# %%
CPratio_res50_03.dropna()
# Out:
#                  收益率   方向  P/C240日Z值   未扣费累计收益    扣费累计收益 百分位阈值    P/C
# 2016-08-16 -0.013095 -1.0   2.170485  0.013095  0.012095  2.5倍  132.0
# 2016-08-17 -0.001755 -1.0   1.838646  0.014850  0.012850  2.5倍  118.0
# 2016-08-18 -0.004001 -1.0   1.616880  0.018851  0.015851  2.5倍  112.0
# 2016-08-19  0.002059 -1.0   1.499593  0.016792  0.012792  2.5倍  108.0
# 2016-08-22 -0.005430 -1.0   1.437044  0.022222  0.017222  2.5倍  106.0
# ...              ...  ...        ...       ...       ...   ...    ...
# 2023-05-26 -0.001907 -1.0  -0.921753 -0.274840 -1.920840  2.5倍   66.0
# 2023-05-29 -0.004426 -1.0  -1.014368 -0.270414 -1.917414  2.5倍   66.0
# 2023-05-30 -0.005157 -1.0  -1.104683 -0.265257 -1.913257  2.5倍   64.0
# 2023-05-31 -0.016486 -1.0  -1.290982 -0.248771 -1.897771  2.5倍   62.0
# 2023-06-01  0.002803 -1.0  -1.231204 -0.251574 -1.901574  2.5倍   58.0
#
# [1650 rows x 7 columns]

# %%
CPratio_res50_03['未扣费累计收益'].plot()
# Out:
# <Axes: >

# %%
CPratio_res50_01['收益率'].loc['2016-02-24':].cumsum().plot(figsize=(20,8))
CPratio_res50_01['未扣费累计收益'].loc['2016-02-24':].plot(figsize=(20,8))
CPratio_res50_01['P/C'].loc['2016-02-24':].plot(secondary_y=True,figsize=(20,8),alpha=0.3)
CPratio_res50_01['P/C240日Z值'].map(lambda x:-5 if x>1.5 else(5 if x<-1.5 else np.nan)).ffill().loc['2016-02-24':].plot(secondary_y=True,figsize=(20,8),color='black')
# Out:
# <Axes: >

# %%
pd.concat([
    CPratio_res50_01,
    CPratio_res50_02,
    CPratio_res50_03
]).to_excel('CPratio_res50_240Zvalue.xlsx')

# %% [markdown]
# ### 值

# %%
same_dt = xy.Index_rets.loc['50',:].index & (CPratio50.shift(1)>1.4).index

# %%
(CPratio50.shift(1)>1.4)
# Out:
# TRADE_DATE
# 2015-02-09    False
# 2015-02-10     True
# 2015-02-11    False
# 2015-02-12    False
# 2015-02-13    False
#               ...
# 2023-05-29    False
# 2023-05-30    False
# 2023-05-31    False
# 2023-06-01    False
# 2023-06-02    False
# Name: CPratio50, Length: 2023, dtype: bool

# %%
(xy.Index_rets.loc['50',same_dt]*(CPratio50.shift(1)>1.2)).cumsum().plot()
# Out:
# <Axes: >

# %%
(xy.Index_rets.loc['50',same_dt]*(CPratio50.shift(1)<1.07)).cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 变化率

# %%
same_dt = xy.Index_rets.loc['50',:].index & (CPratio50.pct_change().shift(1)>0).index

# %%
(CPratio50.shift(1)>1.4)
# Out:
# TRADE_DATE
# 2015-02-09    False
# 2015-02-10     True
# 2015-02-11    False
# 2015-02-12    False
# 2015-02-13    False
#               ...
# 2023-05-29    False
# 2023-05-30    False
# 2023-05-31    False
# 2023-06-01    False
# 2023-06-02    False
# Name: CPratio50, Length: 2023, dtype: bool

# %%
(xy.Index_rets.loc['50',same_dt]*(CPratio50.pct_change().shift(1)>0)).cumsum().plot()
# Out:
# <Axes: >

# %%
(xy.Index_rets.loc['50',same_dt]*(CPratio50.pct_change().shift(1)<-0.)).cumsum().plot()
# Out:
# <Axes: >

# %%
same_dt = xy.Index_rets.columns & CPratio500.index
print(xy.Index_rets.loc['500',same_dt].rolling(1).mean().corr((CPratio50.loc[same_dt]).pct_change().rolling(1).mean().shift(1)))

f = (CPratio500.loc[same_dt]).pct_change().shift(1).dropna()

long = (xy.Index_rets.loc['500',f.index][(f>0).values]).dropna()
short = -(xy.Index_rets.loc['500',f.index][(f<0).values]).dropna()

# pd.concat([
#     long,
#     short
# ]).sort_index().cumsum().plot()
# Out:
# -0.16052717374533146

# %%
fore_ovn_money50, ovn_mom50 = get_ovn_money_mom(xy.IndexMin50jq)
fore_ovn_money300, ovn_mom300 = get_ovn_money_mom(xy.IndexMin300jq)
fore_ovn_money500, ovn_mom500 = get_ovn_money_mom(xy.IndexMin500jq)
fore_ovn_money1000, ovn_mom1000 = get_ovn_money_mom(xy.IndexMin1000jq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[354], line 1
# ----> 1 fore_ovn_money50, ovn_mom50 = get_ovn_money_mom(xy.IndexMin50jq)
#       2 fore_ovn_money300, ovn_mom300 = get_ovn_money_mom(xy.IndexMin300jq)
#       3 fore_ovn_money500, ovn_mom500 = get_ovn_money_mom(xy.IndexMin500jq)
#
# NameError: name 'get_ovn_money_mom' is not defined

# %%
fore_ovn_money
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[355], line 1
# ----> 1 fore_ovn_money
#
# NameError: name 'fore_ovn_money' is not defined

# %%
fore_ovn_money = pd.concat([
    fore_ovn_money50.rename('50'),
    fore_ovn_money300.rename('300'),
    fore_ovn_money500.rename('500'),
    fore_ovn_money1000.rename('1000')
],axis=1).shift(1).T

# %%
fore_ovn_mom
# Out:
#       2009-01-05  2009-01-06  2009-01-07  2009-01-08  2009-01-09  2009-01-12  \
# 50           NaN   -0.005297         0.0   -0.014508   -0.003198   -0.005258
# 300          NaN         NaN         NaN         NaN         NaN         NaN
# 500          NaN         NaN         NaN         NaN         NaN         NaN
# 1000         NaN         NaN         NaN         NaN         NaN         NaN
#
#       2009-01-13  2009-01-14  2009-01-15  2009-01-16  ...  2023-05-10  \
# 50     -0.011628         0.0   -0.012333    0.003112  ...   -0.001478
# 300          NaN         NaN         NaN         NaN  ...   -0.000498
# 500          NaN         NaN         NaN         NaN  ...   -0.000322
# 1000         NaN         NaN         NaN         NaN  ...   -0.001894
#
#       2023-05-11  2023-05-12  2023-05-15  2023-05-16  2023-05-17  2023-05-18  \
# 50      0.003366   -0.001124   -0.000380    0.000746   -0.001122    0.002265
# 300     0.002508   -0.000251    0.000509   -0.000250   -0.001760    0.001772
# 500     0.000969   -0.000972   -0.000818    0.000000   -0.002443    0.001791
# 1000    0.000756   -0.002270    0.000000    0.000381    0.000000   -0.000764
#
#       2023-05-19  2023-05-22  2023-05-23
# 50     -0.003025   -0.000759    0.001504
# 300    -0.002532   -0.000254    0.000757
# 500    -0.001300   -0.000162    0.000000
# 1000   -0.000761   -0.001515    0.000759
#
# [4 rows x 3495 columns]

# %%
fore_ovn_mom = pd.concat([
    ovn_mom50.rename('50'),
    ovn_mom300.rename('300'),
    ovn_mom500.rename('500'),
    ovn_mom1000.rename('1000')
],axis=1).T

# %%
ovn_trs50_1,ovn_trs50_2,ovn_trs50_3,ovn_trs50_4,ovn_trs50_5 = inraday_mom('50',fore_ovn_money,fore_ovn_mom,20)
ovn_trs300_1,ovn_trs300_2,ovn_trs300_3,ovn_trs300_4,ovn_trs300_5 = inraday_mom('300',fore_ovn_money,fore_ovn_mom,20)
ovn_trs500_1,ovn_trs500_2,ovn_trs500_3,ovn_trs500_4,ovn_trs500_5 = inraday_mom('500',fore_ovn_money,fore_ovn_mom,20)
ovn_trs1000_1,ovn_trs1000_2,ovn_trs1000_3,ovn_trs1000_4,ovn_trs1000_5 = inraday_mom('1000',fore_ovn_money,fore_ovn_mom,20)

# %%
ovn_TSR5 = pd.concat([
    ovn_trs50_5.rename('50'),
    ovn_trs300_5.rename('300'),
    ovn_trs500_5.rename('500'),
    ovn_trs1000_5.rename('1000')
],axis=1).shift(1).T

ovn_TSR1 = pd.concat([
    ovn_trs50_1.rename('50'),
    ovn_trs300_1.rename('300'),
    ovn_trs500_1.rename('500'),
    ovn_trs1000_1.rename('1000')
],axis=1).shift(1).T

New_ovn_TSR = (ovn_TSR5 - ovn_TSR5.mean())/ovn_TSR5.std() - (ovn_TSR1 - ovn_TSR1.mean())/ovn_TSR1.std()

# %%
# 分组收益率
xy.cal_rate_group(
    New_ovn_TSR,
    xy.Index_rets,
    group_num=4,
    masks=1
).cumsum().plot()
# Out:
# -8.770686894034968e-05
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %%
long.cumsum().plot()
# Out:
# <Axes: >

# %%
short.cumsum().plot()
# Out:
# <Axes: >

# %%
f = (CPratio500.loc[same_dt]).pct_change().shift(1).dropna()

long = (xy.Index_rets.loc['500',f.index][(f>0).values]).dropna()
short = (-xy.Index_rets.loc['500',f.index][(f<0).values]).dropna()

pd.concat([
    long,
    short
]).sort_index().cumsum().plot()

# %% [markdown]
# #### 多头

# %%
idx_name = '50'
for i in range(15)[::2]:
    i = i / 10
    same_dt = set(xy.Index_rets.T[idx_name].index) & set(f.dropna().index)
    ts_ret = xy.Index_rets.T[idx_name].loc[f[f>i].index&same_dt]
    
    if len(ts_ret) < 1:
        continue
        
    # if i < 1.4:
    #     continue

    win_pct = ts_ret[ts_ret>0].shape[0]/ts_ret.shape[0]
    win_loss_ratio = ts_ret[ts_ret>0].mean()/ts_ret[ts_ret<0].mean()
    
    print('shrh:',i, 'win%:', win_pct,'gainloss%:', win_loss_ratio)
    
    pd.Series(ts_ret.cumsum().rename(i),xy.Index_rets.T[idx_name].index).ffill().plot(legend=True,figsize=(15,8))
    
    if i == 0.8:
        break
# Out:
# shrh: 0.0 win%: 0.4791666666666667 gainloss%: -1.1443868486757478

# %%
ts_ret[ts_ret/ts_ret.shift()<0]
# Out:
# 2016-01-05    0.007775
# 2016-01-07   -0.059137
# 2016-01-08    0.017896
# 2016-01-11   -0.044773
# 2016-01-12    0.005251
#                 ...
# 2022-12-07   -0.005288
# 2022-12-08    0.000842
# 2022-12-12   -0.012118
# 2022-12-13    0.001107
# 2022-12-19   -0.015665
# Name: 50, Length: 406, dtype: float64

# %% [markdown]
# #### 空头

# %%
idx_name = '50'
for i in range(15)[::2]:
    i = i / 10
    same_dt = set(xy.Index_rets.T[idx_name].index) & set(New_TSR1_idx.T[idx_name].dropna().index)
    ts_ret = xy.Index_rets.T[idx_name].loc[New_TSR1_idx.T[idx_name][New_TSR1_idx.T[idx_name]<-i].index&same_dt]
    
    if len(ts_ret) < 1:
        continue
    
    
        
    win_pct = ts_ret[ts_ret>0].shape[0]/ts_ret.shape[0]
    win_loss_ratio = ts_ret[ts_ret>0].mean()/ts_ret[ts_ret<0].mean()
    print('shrh:',i, 'win%:', win_pct,'gainloss%:', win_loss_ratio)
    pd.Series(ts_ret.cumsum().rename(i), xy.Index_rets.T[idx_name].index).ffill().plot(legend=True,figsize=(15,8))
    
    if i == 0.6:
        break
# Out:
# shrh: 0.0 win%: 0.4976958525345622 gainloss%: -0.9456345567608521
# shrh: 0.2 win%: 0.5036585365853659 gainloss%: -0.9324467286715544
# shrh: 0.4 win%: 0.5065274151436031 gainloss%: -0.9112198314775933
# shrh: 0.6 win%: 0.504297994269341 gainloss%: -0.9124547541108481

# %%
ts_ret[ts_ret/ts_ret.shift()<0]
# Out:
# 2016-03-11    0.004498
# 2016-03-17   -0.002175
# 2016-05-12    0.003092
# 2016-05-13   -0.004149
# 2016-08-02    0.000417
#                 ...
# 2023-04-19   -0.008649
# 2023-04-25    0.000288
# 2023-04-26   -0.000479
# 2023-04-27    0.012449
# 2023-05-05   -0.002792
# Name: 50, Length: 372, dtype: float64

# %% [markdown]
# ## 评估

# %% [markdown]
# ### cl-cl

# %%
# 分组收益率
gr_ENPchange = xy.cal_rate_group(
    New_TSR,
    xy.Index_rets,
    group_num=4,
    masks=1
)
gr_ENPchange.cumsum().plot()
# Out:
# -0.005304542389488867
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %%
# 单因子强弱
ENPchange_select, ENPchange_rets = xy.single_Factor_backtest(
    New_TSR1_idx,
    xy.Index_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    _side=1,
    fee=0.000,
    name='ENPchange'
)
# Out:
# 1200.0
# yoy: 0.13930217658595143
#  mdd: -0.24263911959858697
#  sharpe: 0.8083180496890677
#  rankIC: 0.046514285714285716
#  rankIR: 0.060718360034692116
#  win%: 0.519327731092437
#  gain_loss%: -1.0222420349084191

# %%
# 因子截面IC趋势
rankIC = xy.Index_rets.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False).corrwith(New_TSR1_idx.rank(ascending=False))
rankIC.rolling(60).mean().plot(figsize=(15,8),grid=1)
rankIC.mean()
# Out:
# 0.046514285714285716

# %% [markdown]
# ### cl_op

# %%
# 分组收益率
gr_ENPchange = xy.cal_rate_group(
    New_TSR1_idx.T.rolling(1).mean().T.loc[['50', '300', '500', '1000'],'2016-02-28':],
    xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    group_num=4,
    masks=1
)
gr_ENPchange.cumsum().plot()
# Out:
# -0.05012971921705416
# 1 1.0
# 2 1.0
# 3 1.0
# 4 1.0
# <Axes: >

# %%
# 单因子强弱
ENPchange_select, ENPchange_rets = xy.single_Factor_backtest(
    New_TSR1_idx.T.rolling(1).mean().T.loc[['50', '300', '500', '1000'],'2016-02-28':],
    xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':],
    _side=1,
    fee=0.000,
    name='ENPchange'
)
# Out:
# 1196.0
# yoy: -0.037091003278173745
#  mdd: -0.31745989490437765
#  sharpe: -0.772221553049972
#  rankIC: -0.03474285714285715
#  rankIR: -0.0476398609918534
#  win%: 0.47314285714285714
#  gain_loss%: -0.9572870637371589

# %%
# 因子截面IC趋势
rankIC = xy.bonus_open_cl_rets.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False).corrwith(New_TSR1_idx.loc[['50', '300', '500', '1000'],'2016-02-28':].rank(ascending=False))
rankIC.rolling(60).mean().plot(figsize=(15,8),grid=1)
rankIC.mean()
# Out:
# -0.03474285714285715

# %% [markdown]
# ### 择时

# %%
New_TSR
# Out:
#       2016-01-29  2016-02-01  2016-02-02  2016-02-03  2016-02-04  2016-02-05  \
# 50      0.147235    0.226462    1.930968    1.764611    1.508440    1.616129
# 300    -0.350651   -0.180354    1.422594    1.234912    1.238376    1.420999
# 500     0.305772   -0.170631   -1.830181   -0.871996   -0.627495   -0.971579
# 1000   -0.102355    0.124523   -1.523380   -2.127528   -2.119321   -2.065549
#
#       2016-02-15  2016-02-16  2016-02-17  2016-02-18  ...  2023-04-21  \
# 50      1.754330    1.857371    1.925839    1.925839  ...   -0.373158
# 300     1.132818    0.808581    0.548959    0.548959  ...    0.329314
# 500    -0.864574   -2.158523   -2.045980   -2.045980  ...    0.521820
# 1000   -2.022574   -0.507429   -0.428817   -0.428817  ...   -0.477975
#
#       2023-04-24  2023-04-25  2023-04-26  2023-04-27  2023-04-28  2023-05-04  \
# 50      0.157809   -0.898556   -0.218572    0.507251    1.803494    2.533228
# 300    -0.386280   -0.323111    0.273875   -1.049272   -1.349483   -1.132364
# 500     0.278926    1.243249   -0.667052    0.253414   -0.787568   -1.161915
# 1000   -0.050455   -0.021582    0.611749    0.288606    0.333557   -0.238948
#
#       2023-05-05  2023-05-08  2023-05-09
# 50      2.403438    2.283654    2.237313
# 300    -2.331592   -2.250266   -2.602437
# 500    -0.249733   -0.459283    0.304789
# 1000    0.177887    0.425895    0.060335
#
# [4 rows x 1766 columns]

# %%
xy.Index_rets.T['300'].loc[New_TSR.T.dropna()['300'][New_TSR.T.dropna()['300']>1.5].index].cumsum().plot()
# Out:
# <Axes: >

# %%
xy.Index_rets.T['300'].loc[New_TSR.T.dropna()['300'][New_TSR.T.dropna()['300']<-1.5].index].cumsum().plot()
# Out:
# <Axes: >

# %%
New_TSR1_idx.to_csv(r'E:\PyProject\factors\NewFactor\st_TNR.csv')

# %%
New_TSR1_idx
# Out:
#       2016-01-04  2016-01-05  2016-01-06  2016-01-07  2016-01-08  2016-01-11  \
# 50      1.162610    1.178631    1.071053    1.074626    1.172423    1.285050
# 300     0.279121    0.345265    0.455569    0.425751    0.317748    0.176470
# 500    -0.205534   -0.355443   -0.273406   -0.231368   -0.290028   -0.377569
# 1000   -1.236198   -1.168453   -1.253216   -1.269009   -1.200143   -1.083950
#
#       2016-01-12  2016-01-13  2016-01-14  2016-01-15  ...  2023-04-21  \
# 50      1.310740    1.336981    1.133745    1.127067  ...   -1.403125
# 300     0.047593    0.070889    0.265621    0.245809  ...    0.334108
# 500    -0.256579   -0.374990   -0.123074   -0.083570  ...    0.117248
# 1000   -1.101754   -1.032880   -1.276292   -1.289307  ...    0.951769
#
#       2023-04-24  2023-04-25  2023-04-26  2023-04-27  2023-04-28  2023-05-04  \
# 50     -1.293744   -1.175258   -1.489783   -1.418608   -1.378618   -1.321552
# 300     0.242778    0.428628    0.405793    0.106269   -0.044465   -0.009263
# 500    -0.072439   -0.387053    0.422912    0.416233    0.505567    0.236524
# 1000    1.123405    1.133683    0.661078    0.896107    0.917517    1.094291
#
#       2023-05-05  2023-05-08  2023-05-09
# 50     -0.932959    0.169829   -0.659408
# 300    -0.164370    1.346187   -0.764973
# 500     1.414836   -0.827962    1.407017
# 1000   -0.317506   -0.688054    0.017364
#
# [4 rows x 1785 columns]
